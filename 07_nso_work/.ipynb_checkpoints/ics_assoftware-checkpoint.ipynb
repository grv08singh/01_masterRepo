# %%
import numpy as np
import pandas as pd
import pyodbc
import sys
import time
import re
import warnings as wr
wr.filterwarnings('ignore')

# %%
#for 2025-26, year=2025
year = 2025

# %%
yr = year - 2001
mdb_path = r"C:/ICS_Scheme/AS2.0/AS"+str(year)+"/NSSAS"+str(year)+".mdb"

#create connection with mdb database
conn_str = (
    r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
    f'DBQ={mdb_path};'
)
conn = pyodbc.connect(conn_str)

#get all table names from mdb database
#### cursor = conn.cursor()
#### for row in cursor.tables(tableType='TABLE'):
####     print(row.table_name)
#### cursor.close()

#get data from the table - EXPTMASTER
sql_query = "SELECT * FROM EXPTMASTER"
df_ML = pd.read_sql(sql_query, conn)

#get data from the table - Sch20RC7
sql_query = "SELECT * FROM Sch20RC7"
df_sch = (
    pd
    .read_sql(sql_query, conn)
)

conn.close()

# %%
df_ML.drop(columns=[''])
# Out:
#          YEAR SEASONCODE SEASONNAME HSEASONNAME SAMPLE SAMPLENAME HSAMPLENAME  \
# 0     2025-26          1     KHARIF        खरीफ      1    CENTRAL   केन्द्रीय
# 1     2025-26          1     KHARIF        खरीफ      1    CENTRAL   केन्द्रीय
# 2     2025-26          4       RABI         रबी      1    CENTRAL   केन्द्रीय
# 3     2025-26          4       RABI         रबी      1    CENTRAL   केन्द्रीय
# 4     2025-26          4       RABI         रबी      1    CENTRAL   केन्द्रीय
# ...       ...        ...        ...         ...    ...        ...         ...
# 2035  2025-26          4     RABI-I       रबी-I      2      STATE       राज्य
# 2036  2025-26          1     KHARIF        खरीफ      2      STATE       राज्य
# 2037  2025-26          1     KHARIF        खरीफ      2      STATE       राज्य
# 2038  2025-26          4     RABI-I       रबी-I      2      STATE       राज्य
# 2039  2025-26          4     RABI-I       रबी-I      2      STATE       राज्य
#
# ...
