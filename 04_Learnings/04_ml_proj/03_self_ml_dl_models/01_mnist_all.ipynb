# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from PIL import Image
import time

from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score

from sklearn.linear_model import RidgeClassifier,SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

from tensorflow import keras as tfk
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

import warnings as wr
wr.filterwarnings('ignore')

# %%
(X_train,y_train),(X_test,y_test) = tfk.datasets.mnist.load_data()

# %%
r = 3
c = 20
total = r*c

n = np.random.randint(0, X_train.shape[0], total)

fig, ax = plt.subplots(nrows=r, ncols=c, figsize=(c, r))

for ix,val in enumerate(n):
    row=ix//c
    col=ix%c
    ax[row,col].imshow(X_train[val],cmap='gray')
    ax[row,col].set_title(str(y_train[val]))
    ax[row,col].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### flatten data

# %%
X_train_flattened = X_train.reshape(X_train.shape[0], X_train.shape[1]*X_train.shape[2])
X_test_flattened = X_test.reshape(X_test.shape[0], X_test.shape[1]*X_test.shape[2])

# %% [markdown]
# #### dataset seems fairly balanced

# %% [markdown]
# #### label encoding is not required

# %% [markdown]
# #### scaling data for ML models

# %%
X_train_scaled = X_train_flattened/255
X_test_scaled = X_test_flattened/255

# %% [markdown]
# #### scaling data for DL models

# %%
#Normalizing data
X_train_normalized = X_train/255
X_test_normalized = X_test/255

# %% [markdown]
# #### ML Models on three datasets will be created,
# #### 1) raw data:    `X_train_raw`,      `X_test_raw`
# #### 2) after dimensionality reduction using PCA:    `X_train_pca`,      `X_test_pca`
# #### 3) after dimensionality reduction using LDA:    `X_train_lda`,      `X_test_lda`
#
# #### DL Models (ANN, CNN) on the RAW dataset will be created

# %%
X_train_raw = X_train_scaled.copy()
X_test_raw = X_test_scaled.copy()

# %%
X_train_raw.shape
# Out:
# (60000, 784)

# %%
X_train_pca = X_train_scaled.copy()
X_test_pca = X_test_scaled.copy()

pca = PCA(n_components=0.95)

X_train_pca = pca.fit_transform(X_train_pca)
X_test_pca = pca.transform(X_test_pca)

# %%
X_train_pca.shape
# Out:
# (60000, 154)

# %%
X_train_lda = X_train_scaled.copy()
X_test_lda = X_test_scaled.copy()

lda = LinearDiscriminantAnalysis(n_components=9)

X_train_lda = lda.fit_transform(X_train_lda, y_train)
X_test_lda = lda.transform(X_test_lda)

# %%
X_train_lda.shape
# Out:
# (60000, 9)

# %% [markdown]
# #### Global parameters

# %%
cv=5
n_jobs=-6
verbose=5

# %% [markdown]
# #### Global methods

# %%
def custom_refit(cv_results):
    mean_acc = cv_results["mean_test_accuracy"]
    max_acc = mean_acc.max()
    best_idx_candidates = np.where(mean_acc == max_acc)[0]
    fit_times = cv_results["mean_fit_time"]
    best_idx = best_idx_candidates[np.argmin(fit_times[best_idx_candidates])]
    return best_idx

# %% [markdown]
# #### 1.1 SGD Classifier Model with Raw Data

# %%
#manual change - starts
model_name = "SGD Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = SGDClassifier()

#Tuning Hyperparameters
param = {
    'loss':['log_loss','hinge'],
    'penalty':['l1','l2','elasticnet'],
    'max_iter':[100,200,300,400,500]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SGDClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Time taken by GridSearchCV: 1475.6853604316711
# SGD Classifier | Raw Data | best loss : log_loss
#
# SGD Classifier | Raw Data | best max_iter : 300
#
# SGD Classifier | Raw Data | best penalty : l2
#
# SGD Classifier | Raw Data | best train accuracy : 0.9115833333333334
#
# SGD Classifier | Raw Data | Final test Accuracy : 0.9144

# %% [markdown]
# #### 1.2 SGD Classifier model with PCA data

# %%
#manual change - starts
model_name = "SGD Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = SGDClassifier()

#Tuning Hyperparameters
param = {
    'loss':['log_loss','hinge'],
    'penalty':['l1','l2','elasticnet'],
    'max_iter':[100,200,300,400,500]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SGDClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Time taken by GridSearchCV: 503.1558187007904
# SGD Classifier | PCA Data | best loss : log_loss
#
# SGD Classifier | PCA Data | best max_iter : 400
#
# SGD Classifier | PCA Data | best penalty : l2
#
# SGD Classifier | PCA Data | best train accuracy : 0.9093333333333333
#
# SGD Classifier | PCA Data | Final test Accuracy : 0.9155

# %% [markdown]
# #### 1.3 SGD Classifier model with LDA data

# %%
#manual change - starts
model_name = "SGD Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = SGDClassifier()

#Tuning Hyperparameters
param = {
    'loss':['log_loss','hinge'],
    'penalty':['l1','l2','elasticnet'],
    'max_iter':[100,200,300,400,500]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SGDClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Time taken by GridSearchCV: 21.10083842277527
# SGD Classifier | LDA Data | best loss : log_loss
#
# SGD Classifier | LDA Data | best max_iter : 400
#
# SGD Classifier | LDA Data | best penalty : l2
#
# SGD Classifier | LDA Data | best train accuracy : 0.8785833333333333
#
# SGD Classifier | LDA Data | Final test Accuracy : 0.8801

# %% [markdown]
# #### 2.1 Ridge Classifier model with Raw Data

# %%
#manual change - starts
model_name = "Ridge Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = RidgeClassifier()

#Tuning Hyperparameters
param = {
    'alpha' : [1, 0.1, 0.01, 0.001],
    'fit_intercept': [True,False],
    'copy_X': [True,False],
    'max_iter':[200,500,1000]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RidgeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Time taken by GridSearchCV: 61.78044652938843
# Ridge Classifier | Raw Data | best alpha : 1
#
# Ridge Classifier | Raw Data | best copy_X : True
#
# Ridge Classifier | Raw Data | best fit_intercept : True
#
# Ridge Classifier | Raw Data | best max_iter : 200
#
# Ridge Classifier | Raw Data | best train accuracy : 0.84985
#
# Ridge Classifier | Raw Data | Final test Accuracy : 0.8604

# %% [markdown]
# #### 2.2 Ridge Classifier model with PCA data

# %%
#manual change - starts
model_name = "Ridge Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = RidgeClassifier()

#Tuning Hyperparameters
param = {
    'alpha' : [1, 0.1, 0.01, 0.001],
    'fit_intercept': [True,False],
    'copy_X': [True,False],
    'max_iter':[200,500,1000]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RidgeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Time taken by GridSearchCV: 7.273421287536621
# Ridge Classifier | PCA Data | best alpha : 1
#
# Ridge Classifier | PCA Data | best copy_X : True
#
# Ridge Classifier | PCA Data | best fit_intercept : False
#
# Ridge Classifier | PCA Data | best max_iter : 200
#
# Ridge Classifier | PCA Data | best train accuracy : 0.8511833333333334
#
# Ridge Classifier | PCA Data | Final test Accuracy : 0.8613

# %% [markdown]
# #### 2.3 Ridge Classifier model with LDA data

# %%
#manual change - starts
model_name = "Ridge Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = RidgeClassifier()

#Tuning Hyperparameters
param = {
    'alpha' : [1, 0.1, 0.01, 0.001],
    'fit_intercept': [True,False],
    'copy_X': [True,False],
    'max_iter':[200,500,1000]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RidgeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Time taken by GridSearchCV: 1.232696533203125
# Ridge Classifier | LDA Data | best alpha : 1
#
# Ridge Classifier | LDA Data | best copy_X : True
#
# Ridge Classifier | LDA Data | best fit_intercept : False
#
# Ridge Classifier | LDA Data | best max_iter : 200
#
# Ridge Classifier | LDA Data | best train accuracy : 0.8593
#
# Ridge Classifier | LDA Data | Final test Accuracy : 0.8612

# %% [markdown]
# #### 3.1 KNN Classifier model with raw data

# %%
#manual change - starts
model_name = "KNN Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = KNeighborsClassifier()

#Tuning Hyperparameters
param = {
    'n_neighbors' : [3,5,7,9],
    'algorithm': ['auto','ball_tree','kd_tree','brute'],
    'p': [1,2]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = KNeighborsClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 16061.523204565048
# KNN Classifier | Raw Data | best algorithm : auto
#
# KNN Classifier | Raw Data | best n_neighbors : 3
#
# KNN Classifier | Raw Data | best p : 2
#
# KNN Classifier | Raw Data | best train accuracy : 0.9700666666666666
#
# KNN Classifier | Raw Data | Final test Accuracy : 0.9705

# %% [markdown]
# #### 3.2 KNN Classifier model with PCA data

# %%
#manual change - starts
model_name = "KNN Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = KNeighborsClassifier()

#Tuning Hyperparameters
param = {
    'n_neighbors' : [3,5,7,9],
    'algorithm': ['auto','ball_tree','kd_tree','brute'],
    'p': [1,2]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = KNeighborsClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 5050.994165658951
# KNN Classifier | PCA Data | best algorithm : auto
#
# KNN Classifier | PCA Data | best n_neighbors : 3
#
# KNN Classifier | PCA Data | best p : 2
#
# KNN Classifier | PCA Data | best train accuracy : 0.9724833333333333
#
# KNN Classifier | PCA Data | Final test Accuracy : 0.9722

# %% [markdown]
# #### 3.3 KNN Classifier model with LDA data

# %%
#manual change - starts
model_name = "KNN Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = KNeighborsClassifier()

#Tuning Hyperparameters
param = {
    'n_neighbors' : [3,5,7,9],
    'algorithm': ['auto','ball_tree','kd_tree','brute'],
    'p': [1,2]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = KNeighborsClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 262.67334246635437
# KNN Classifier | LDA Data | best algorithm : auto
#
# KNN Classifier | LDA Data | best n_neighbors : 7
#
# KNN Classifier | LDA Data | best p : 2
#
# KNN Classifier | LDA Data | best train accuracy : 0.9210166666666666
#
# KNN Classifier | LDA Data | Final test Accuracy : 0.9183

# %% [markdown]
# #### 4.1 Support Vector Classifier model with raw data

# %%
#manual change - starts
model_name = "SVC Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = SVC()

#Tuning Hyperparameters
param = {
    'kernel' : ['linear','poly','rbf','sigmoid'],
    'degree': [3,4,5,6],
    'gamma': ['auto','scale']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SVC(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 19288.039867162704
# SVC Classifier | Raw Data | best degree : 3
#
# SVC Classifier | Raw Data | best gamma : scale
#
# SVC Classifier | Raw Data | best kernel : rbf
#
# SVC Classifier | Raw Data | best train accuracy : 0.9769333333333334
#
# SVC Classifier | Raw Data | Final test Accuracy : 0.9792

# %% [markdown]
# #### 4.2 Support Vector Classifier with PCA data

# %%
#manual change - starts
model_name = "SVC Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = SVC()

#Tuning Hyperparameters
param = {
    'kernel' : ['linear','poly','rbf','sigmoid'],
    'degree': [3,4,5,6],
    'gamma': ['auto','scale']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    #n_jobs=-1,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SVC(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 10945.208495855331
# SVC Classifier | PCA Data | best degree : 3
#
# SVC Classifier | PCA Data | best gamma : scale
#
# SVC Classifier | PCA Data | best kernel : poly
#
# SVC Classifier | PCA Data | best train accuracy : 0.9816166666666668
#
# SVC Classifier | PCA Data | Final test Accuracy : 0.9826

# %% [markdown]
# #### 4.3 Support Vector Classifier with LDA data

# %%
#manual change - starts
model_name = "SVC Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = SVC()

#Tuning Hyperparameters
param = {
    'kernel' : ['linear','poly','rbf','sigmoid'],
    'degree': [3,4,5,6],
    'gamma': ['auto','scale']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = SVC(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Time taken by GridSearchCV: 350.075590133667
# SVC Classifier | LDA Data | best degree : 3
#
# SVC Classifier | LDA Data | best gamma : auto
#
# SVC Classifier | LDA Data | best kernel : rbf
#
# SVC Classifier | LDA Data | best train accuracy : 0.9255333333333334
#
# SVC Classifier | LDA Data | Final test Accuracy : 0.9255

# %% [markdown]
# #### 5.1 Decision Tree Classifier model with raw data

# %%
#manual change - starts
model_name = "Decision Tree Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = DecisionTreeClassifier()

#Tuning Hyperparameters
param = {
    'criterion' : ['gini','entropy','log_loss'],
    'splitter': ['best','random'],
    'max_depth': [None,5,10,15],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = DecisionTreeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Time taken by GridSearchCV: 187.3831799030304
# Decision Tree Classifier | Raw Data | best criterion : entropy
#
# Decision Tree Classifier | Raw Data | best max_depth : 15
#
# Decision Tree Classifier | Raw Data | best max_features : None
#
# Decision Tree Classifier | Raw Data | best splitter : best
#
# Decision Tree Classifier | Raw Data | best train accuracy : 0.87425
#
# Decision Tree Classifier | Raw Data | Final test Accuracy : 0.8865

# %% [markdown]
# #### 5.2 Decision Tree Classifier model with PCA data

# %%
#manual change - starts
model_name = "Decision Tree Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = DecisionTreeClassifier()

#Tuning Hyperparameters
param = {
    'criterion' : ['gini','entropy','log_loss'],
    'splitter': ['best','random'],
    'max_depth': [None,5,10,15],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = DecisionTreeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Time taken by GridSearchCV: 267.2103946208954
# Decision Tree Classifier | PCA Data | best criterion : log_loss
#
# Decision Tree Classifier | PCA Data | best max_depth : 15
#
# Decision Tree Classifier | PCA Data | best max_features : None
#
# Decision Tree Classifier | PCA Data | best splitter : best
#
# Decision Tree Classifier | PCA Data | best train accuracy : 0.8332333333333335
#
# Decision Tree Classifier | PCA Data | Final test Accuracy : 0.8439

# %% [markdown]
# #### 5.3 Decision Tree Classifier model with LDA data

# %%
#manual change - starts
model_name = "Decision Tree Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = DecisionTreeClassifier()

#Tuning Hyperparameters
param = {
    'criterion' : ['gini','entropy','log_loss'],
    'splitter': ['best','random'],
    'max_depth': [None,3,4,5,8,10,15],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = DecisionTreeClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
# Time taken by GridSearchCV: 16.08873677253723
# Decision Tree Classifier | LDA Data | best criterion : gini
#
# Decision Tree Classifier | LDA Data | best max_depth : 15
#
# Decision Tree Classifier | LDA Data | best max_features : None
#
# Decision Tree Classifier | LDA Data | best splitter : best
#
# Decision Tree Classifier | LDA Data | best train accuracy : 0.8690333333333333
#
# Decision Tree Classifier | LDA Data | Final test Accuracy : 0.8697

# %% [markdown]
# #### 6.1 Random Forest Classifier model with raw data

# %%
#manual change - starts
model_name = "Random Forest Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = RandomForestClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'criterion' : ['gini','entropy','log_loss'],
    'max_depth': [1,2,3,4],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RandomForestClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# Time taken by GridSearchCV: 68501.0784406662
# Random Forest Classifier | Raw Data | best criterion : gini
#
# Random Forest Classifier | Raw Data | best max_depth : None
#
# Random Forest Classifier | Raw Data | best max_features : sqrt
#
# Random Forest Classifier | Raw Data | best n_estimators : 400
#
# Random Forest Classifier | Raw Data | best train accuracy : 0.9684000000000001
#
# Random Forest Classifier | Raw Data | Final test Accuracy : 0.9713

# %% [markdown]
# #### 6.2 Random Forest Classifier model with PCA data

# %%
#manual change - starts
model_name = "Random Forest Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = RandomForestClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'criterion' : ['gini','entropy','log_loss'],
    'max_depth': [1,2,3,4],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RandomForestClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Time taken by GridSearchCV: 36996.70253658295
# Random Forest Classifier | PCA Data | best criterion : gini
#
# Random Forest Classifier | PCA Data | best max_depth : 4
#
# Random Forest Classifier | PCA Data | best max_features : log2
#
# Random Forest Classifier | PCA Data | best n_estimators : 300
#
# Random Forest Classifier | PCA Data | best train accuracy : 0.8090666666666667
#
# Random Forest Classifier | PCA Data | Final test Accuracy : 0.8145

# %% [markdown]
# #### 6.3 Random Forest Classifier model with LDA data

# %%
#manual change - starts
model_name = "Random Forest Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = RandomForestClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'criterion' : ['gini','entropy','log_loss'],
    'max_depth': [1,2,3,4],
    'max_features':[None,'sqrt','log2']
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = RandomForestClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Time taken by GridSearchCV: 3248.2439267635345
# Random Forest Classifier | LDA Data | best criterion : log_loss
#
# Random Forest Classifier | LDA Data | best max_depth : 4
#
# Random Forest Classifier | LDA Data | best max_features : sqrt
#
# Random Forest Classifier | LDA Data | best n_estimators : 300
#
# Random Forest Classifier | LDA Data | best train accuracy : 0.8541666666666667
#
# Random Forest Classifier | LDA Data | Final test Accuracy : 0.855

# %% [markdown]
# #### 7.1 Gradient Boosting Classifier model with raw data

# %%
#manual change - starts
model_name = "Gradient Boosting Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = GradientBoostingClassifier()

#Tuning Hyperparameters
param = {
    'loss' : ['log_loss','exponential'],
    'learning_rate' : [0.1,0.05,0.01],
    'n_estimators': [100,200,300]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = GradientBoostingClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Time taken by GridSearchCV: 73003.04029273987
# Gradient Boosting Classifier | Raw Data | best learning_rate : 0.1
#
# Gradient Boosting Classifier | Raw Data | best loss : log_loss
#
# Gradient Boosting Classifier | Raw Data | best n_estimators : 300
#
# Gradient Boosting Classifier | Raw Data | best train accuracy : 0.9620333333333333
#
# Gradient Boosting Classifier | Raw Data | Final test Accuracy : 0.9677

# %% [markdown]
# #### 7.2 Gradient Boosting Classifier model with PCA data

# %%
#manual change - starts
model_name = "Gradient Boosting Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = GradientBoostingClassifier()

#Tuning Hyperparameters
param = {
    'loss' : ['log_loss','exponential'],
    'learning_rate' : [0.1,0.05,0.01],
    'n_estimators': [100,200,300]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = GradientBoostingClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Time taken by GridSearchCV: 83928.1966638565
# Gradient Boosting Classifier | PCA Data | best learning_rate : 0.1
#
# Gradient Boosting Classifier | PCA Data | best loss : log_loss
#
# Gradient Boosting Classifier | PCA Data | best n_estimators : 300
#
# Gradient Boosting Classifier | PCA Data | best train accuracy : 0.9411333333333334
#
# Gradient Boosting Classifier | PCA Data | Final test Accuracy : 0.9469

# %% [markdown]
# #### 7.3 Gradient Boosting Classifier model with LDA data

# %%
#manual change - starts
model_name = "Gradient Boosting Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = GradientBoostingClassifier()

#Tuning Hyperparameters
param = {
    'loss' : ['log_loss','exponential'],
    'learning_rate' : [0.1,0.05,0.01],
    'n_estimators': [100,200,300]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = GradientBoostingClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Time taken by GridSearchCV: 3946.0926377773285
# Gradient Boosting Classifier | LDA Data | best learning_rate : 0.1
#
# Gradient Boosting Classifier | LDA Data | best loss : log_loss
#
# Gradient Boosting Classifier | LDA Data | best n_estimators : 300
#
# Gradient Boosting Classifier | LDA Data | best train accuracy : 0.9071833333333332
#
# Gradient Boosting Classifier | LDA Data | Final test Accuracy : 0.9068

# %% [markdown]
# #### 8.1 XGBoost Classifier model with raw Data

# %%
#manual change - starts
model_name = "XGBoost Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m1 = XGBClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'max_depth' : [1,2,3,4],
    'learning_rate' : [0.1,0.05,0.01]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = XGBClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Time taken by GridSearchCV: 15370.534150600433
# XGBoost Classifier | Raw Data | best learning_rate : 0.1
#
# XGBoost Classifier | Raw Data | best max_depth : 4
#
# XGBoost Classifier | Raw Data | best n_estimators : 300
#
# XGBoost Classifier | Raw Data | best train accuracy : 0.9702333333333334
#
# XGBoost Classifier | Raw Data | Final test Accuracy : 0.974

# %% [markdown]
# #### 8.2 XGBoost Classifier model with PCA Data

# %%
#manual change - starts
model_name = "XGBoost Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m1 = XGBClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'max_depth' : [1,2,3,4],
    'learning_rate' : [0.1,0.05,0.01]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = XGBClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Time taken by GridSearchCV: 3838.189821243286
# XGBoost Classifier | PCA Data | best learning_rate : 0.1
#
# XGBoost Classifier | PCA Data | best max_depth : 4
#
# XGBoost Classifier | PCA Data | best n_estimators : 300
#
# XGBoost Classifier | PCA Data | best train accuracy : 0.9535
#
# XGBoost Classifier | PCA Data | Final test Accuracy : 0.9577

# %% [markdown]
# #### 8.3 XGBoost Classifier model with LDA Data

# %%
#manual change - starts
model_name = "XGBoost Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m1 = XGBClassifier()

#Tuning Hyperparameters
param = {
    'n_estimators' : [100,200,300],
    'max_depth' : [1,2,3,4],
    'learning_rate' : [0.1,0.05,0.01]
}
#manual change - ends

gs = GridSearchCV(
    estimator=m1,
    param_grid=param,
    cv = cv,
    scoring='accuracy',
    n_jobs=n_jobs,
    verbose=verbose
)
start_time = time.time()
gs.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#Printing Best Hyperparameters
for key,val in gs.best_params_.items():
    print(f"{model_name} | {data_name} | best {key} : {val}\n")
print(f"{model_name} | {data_name} | best train accuracy : {gs.best_score_}\n")

#manual change - starts
#fitting model after hyperparameter tuning
m2 = XGBClassifier(**gs.best_params_)
#manual change - ends

m2.fit(X1, y_train)

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Time taken by GridSearchCV: 194.34350061416626
# XGBoost Classifier | LDA Data | best learning_rate : 0.1
#
# XGBoost Classifier | LDA Data | best max_depth : 4
#
# XGBoost Classifier | LDA Data | best n_estimators : 300
#
# XGBoost Classifier | LDA Data | best train accuracy : 0.9147833333333335
#
# XGBoost Classifier | LDA Data | Final test Accuracy : 0.914

# %% [markdown]
# #### 9.1 Naive Bayes Classifier model with raw data

# %%
#manual change - starts
model_name = "Naive Bayes Classifier"
data_name = "Raw Data"
X1 = X_train_raw.copy()
X2 = X_test_raw.copy()
m2 = GaussianNB()
#manual change - ends

start_time = time.time()
m2.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Time taken by GridSearchCV: 0.7521016597747803
# Naive Bayes Classifier | Raw Data | Final test Accuracy : 0.5558

# %% [markdown]
# #### 9.2 Naive Bayes Classifier model with PCA data

# %%
#manual change - starts
model_name = "Naive Bayes Classifier"
data_name = "PCA Data"
X1 = X_train_pca.copy()
X2 = X_test_pca.copy()
m2 = GaussianNB()
#manual change - ends

start_time = time.time()
m2.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Time taken by GridSearchCV: 0.15609169006347656
# Naive Bayes Classifier | PCA Data | Final test Accuracy : 0.8664

# %% [markdown]
# #### 9.3 Naive Bayes Classifier model with LDA data

# %%
#manual change - starts
model_name = "Naive Bayes Classifier"
data_name = "LDA Data"
X1 = X_train_lda.copy()
X2 = X_test_lda.copy()
m2 = GaussianNB()
#manual change - ends

start_time = time.time()
m2.fit(X1, y_train)
end_time = time.time()
print(f"Time taken by GridSearchCV: {end_time - start_time}")

#prediction after hyperparameter tuning
y_pred = m2.predict(X2)
accuracy = accuracy_score(y_test, y_pred)
print(f"{model_name} | {data_name} | Final test Accuracy : {accuracy}")
# Out:
# Time taken by GridSearchCV: 0.022133827209472656
# Naive Bayes Classifier | LDA Data | Final test Accuracy : 0.8799

# %% [markdown]
# #### 10.1 ANN model with original images

# %%
#create model
model = tfk.models.Sequential()

#input layer
model.add(
    tfk.layers.Flatten(
        input_shape = X_train_normalized.shape[1:]
    )
)

#1st hidden layer
model.add(
    tfk.layers.Dense(
        units = 128,
        activation = tfk.activations.relu
    )
)

#2nd hidden layer
model.add(
    tfk.layers.Dense(
        units = 128,
        activation = tfk.activations.relu
    )
)

#output layer
model.add(
    tfk.layers.Dense(
        units = 10,
        activation = tfk.activations.softmax
    )
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │         100,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#optimizer
adam_optimizer = tfk.optimizers.Adam(learning_rate = 0.01)

#compile model
model.compile(
    optimizer = adam_optimizer,
    loss = tfk.losses.sparse_categorical_crossentropy,
    metrics = ['accuracy']
)

#train and validate the model
start_time = time.time()
training_history = model.fit(
    X_train_normalized, 
    y_train, 
    epochs=20,
    validation_data=(X_test_normalized, y_test)
)
end_time = time.time()
duration = end_time - start_time
print(f"Time taken to train ANN model: {duration}")
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9205 - loss: 0.2722 - val_accuracy: 0.9391 - val_loss: 0.2409
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9494 - loss: 0.1824 - val_accuracy: 0.9514 - val_loss: 0.1835
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9582 - loss: 0.1553 - val_accuracy: 0.9605 - val_loss: 0.1542
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9613 - loss: 0.1467 - val_accuracy: 0.9534 - val_loss: 0.2022
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9664 - loss: 0.1299 - val_accuracy: 0.9624 - val_loss: 0.1576
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9690 - loss: 0.1243 - val_accuracy: 0.9592 - val_loss: 0.1891
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9699 - loss: 0.1216 - val_accuracy: 0.9576 - val_loss: 0.1872
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9718 - loss: 0.1136 - val_accuracy: 0.9595 - val_loss: 0.2000
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9733 - loss: 0.1164 - val_accuracy: 0.9635 - val_loss: 0.1920
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9747 - loss: 0.1026 - val_accuracy: 0.9529 - val_loss: 0.2094
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9744 - loss: 0.1106 - val_accuracy: 0.9652 - val_loss: 0.1801
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9747 - loss: 0.1093 - val_accuracy: 0.9654 - val_loss: 0.1756
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9771 - loss: 0.0915 - val_accuracy: 0.9665 - val_loss: 0.1828
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9767 - loss: 0.0981 - val_accuracy: 0.9587 - val_loss: 0.2169
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9787 - loss: 0.0903 - val_accuracy: 0.9659 - val_loss: 0.2171
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9780 - loss: 0.0939 - val_accuracy: 0.9613 - val_loss: 0.2572
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9774 - loss: 0.0964 - val_accuracy: 0.9668 - val_loss: 0.2258
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9776 - loss: 0.0958 - val_accuracy: 0.9669 - val_loss: 0.2145
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9801 - loss: 0.0853 - val_accuracy: 0.9634 - val_loss: 0.2544
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9790 - loss: 0.0914 - val_accuracy: 0.9624 - val_loss: 0.2763
# Time taken to train ANN model: 91.5857253074646

# %% [markdown]
# #### 10.2 CNN model with original images

# %%
X_test_normalized.shape
# Out:
# (10000, 28, 28)

# %%
#cnn requires 4d array, therefore, reshaping to 4d data
X_train_n = X_train_normalized.reshape((60000, 28, 28, 1))
X_test_n = X_test_normalized.reshape((10000, 28, 28, 1))

# %%
#create model
model = tfk.models.Sequential()

#1st convolutional layer
model.add(
    tfk.layers.Conv2D(
        32,                     #32 filters
        (3,3),                  #kernel size 3x3
        activation='relu',
        input_shape = X_train_n.shape[1::]
    )
)

#1st pooling layer, pool size 2x2, reduce spatial dimensions by half
model.add(tfk.layers.MaxPool2D((2,2)))

#2nd convolutional layer
model.add(
    tfk.layers.Conv2D(
        64,                     #64 filters
        (3,3),                  #kernel size 3x3
        activation='relu'
    )
)

#2nd pooling layer
model.add(tfk.layers.MaxPool2D((2,2)))

#3rd convolutional layer, but no Max Pooling
model.add(
    tfk.layers.Conv2D(
        64,
        (3,3),
        activation='relu'
    )
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 3, 3, 64)            │          36,928 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 55,744 (217.75 KB)
#  Trainable params: 55,744 (217.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#adding ANN block on top of CNN
#adding Flatten layer
model.add(tfk.layers.Flatten())

#adding a dense layer
model.add(
    tfk.layers.Dense(
        64,
        activation='relu'
    )
)

#adding output layer
model.add(
    tfk.layers.Dense(10)
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 3, 3, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 576)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#compiling model
model.compile(
    optimizer = 'adam',
    loss = tfk.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['accuracy']
)

# %%
#training the model
history_01 = model.fit(
    X_train_n, 
    y_train, 
    epochs=20,
    validation_data = (X_test_n, y_test)
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.9528 - loss: 0.1504 - val_accuracy: 0.9833 - val_loss: 0.0524
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9855 - loss: 0.0470 - val_accuracy: 0.9867 - val_loss: 0.0409
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9888 - loss: 0.0348 - val_accuracy: 0.9868 - val_loss: 0.0378
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9923 - loss: 0.0255 - val_accuracy: 0.9913 - val_loss: 0.0290
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9931 - loss: 0.0213 - val_accuracy: 0.9904 - val_loss: 0.0323
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9949 - loss: 0.0171 - val_accuracy: 0.9913 - val_loss: 0.0301
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9953 - loss: 0.0142 - val_accuracy: 0.9913 - val_loss: 0.0288
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9966 - loss: 0.0111 - val_accuracy: 0.9914 - val_loss: 0.0338
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9917 - val_loss: 0.0310
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.9918 - val_loss: 0.0374
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9970 - loss: 0.0085 - val_accuracy: 0.9927 - val_loss: 0.0355
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.9893 - val_loss: 0.0522
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9978 - loss: 0.0071 - val_accuracy: 0.9893 - val_loss: 0.0470
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.9921 - val_loss: 0.0374
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9919 - val_loss: 0.0374
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9929 - val_loss: 0.0400
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9981 - loss: 0.0065 - val_accuracy: 0.9928 - val_loss: 0.0366
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9908 - val_loss: 0.0495
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9931 - val_loss: 0.0383
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9928 - val_loss: 0.0443

# %%
plt.plot(history_01.history['accuracy'], color='magenta', label='Train Accuracy')
plt.plot(history_01.history['val_accuracy'], color='green', label='Test Accuracy')
plt.legend()
plt.show()
