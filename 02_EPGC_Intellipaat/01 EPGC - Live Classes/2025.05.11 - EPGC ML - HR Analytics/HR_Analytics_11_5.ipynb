# %%
https://drive.google.com/file/d/1YzfWGHzNIZOqtTmfeh-HKcCE3SwOG52a/view?usp=sharing

# %%
import pandas as pd

# %%
df=pd.read_csv(r'/content/HR_DataSet.csv')

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
#percentage of attrition
df['left'].value_counts().loc[1]*100/len(df)
# Out:
# np.float64(16.604119756484028)

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        11991.000000     11991.000000    11991.000000
# mean             0.629658         0.716683        3.802852
# std              0.241070         0.168343        1.163238
# min              0.090000         0.360000        2.000000
# 25%              0.480000         0.570000        3.000000
# 50%              0.660000         0.720000        4.000000
# 75%              0.820000         0.860000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          11991.000000        11991.000000   11991.000000  11991.000000
# mean             200.473522            3.364857       0.154282      0.166041
# std               48.727813            1.330240       0.361234      0.372133
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df['number_project'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3])

# %%
df['number_project'].value_counts()
# Out:
# number_project
# 4    3685
# 3    3520
# 5    2233
# 2    1582
# 6     826
# 7     145
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df,x='number_project',hue='left')
plt.show()

# %%
df['time_spend_company'].unique()
# Out:
# array([ 3,  6,  4,  5,  2,  8, 10,  7])

# %%
sns.countplot(data=df,x='time_spend_company',hue='left')
# Out:
# <Axes: xlabel='time_spend_company', ylabel='count'>

# %%
#experience >6,
df1=df[df['time_spend_company']>6]

# %%
sns.countplot(data=df1,x='number_project',hue='left')
plt.show()

# %%
#projects>=6
df1=df[df['number_project']>=6]#6,7 projects

# %%
fig,axis=plt.subplots(nrows=1,ncols=2,figsize=(16,5))
sns.countplot(data=df1,x='number_project',hue='left',ax=axis[1])
sns.countplot(data=df1,x='time_spend_company',hue='left',ax=axis[0])
plt.show()

# %%
#projects>=6, time_spend<=3
df1=df[(df['number_project']>=6)&(df['time_spend_company']<=3)]
df1.head()
# Out:
#      satisfaction_level  last_evaluation  number_project  \
# 50                 0.13             0.78               6
# 196                0.27             0.54               7
# 252                0.19             0.59               7
# 666                0.46             0.62               6
# 710                0.64             0.90               6
#
#      average_montly_hours  time_spend_company  Work_accident  left  \
# 50                    152                   2              0     1
# 196                   278                   3              0     1
# 252                   192                   3              0     1
# 666                   213                   3              0     1
# 710                   252                   2              0     1
#
#      promotion_last_5years Department salary
# 50                       0    support    low
# 196                      0  technical    low
# 252                      0      sales    low
# ...

# %%
fig,axis=plt.subplots(nrows=1,ncols=2,figsize=(16,5))
sns.countplot(data=df1,x='Department',hue='left',ax=axis[1])
sns.countplot(data=df1,x='salary',hue='left',ax=axis[0])
plt.xticks(rotation=90)
plt.show()

# %%
df['average_montly_hours'].unique()
# Out:
# array([157, 262, 272, 223, 159, 153, 247, 259, 224, 142, 135, 305, 234,
#        148, 137, 143, 160, 255, 282, 147, 304, 139, 158, 242, 239, 128,
#        132, 294, 134, 145, 140, 246, 126, 306, 152, 269, 127, 281, 276,
#        182, 273, 307, 309, 225, 226, 308, 244, 286, 161, 264, 277, 275,
#        149, 295, 151, 249, 291, 232, 130, 129, 155, 265, 279, 284, 221,
#        154, 150, 267, 257, 177, 144, 289, 258, 263, 251, 133, 216, 300,
#        138, 260, 183, 250, 292, 283, 245, 256, 278, 240, 136, 301, 243,
#        296, 274, 164, 146, 261, 285, 141, 297, 156, 287, 219, 254, 228,
#        131, 252, 236, 270, 298, 192, 248, 266, 238, 229, 233, 268, 231,
#        253, 302, 271, 290, 235, 293, 241, 218, 199, 180, 195, 237, 227,
#        172, 206, 181, 217, 310, 214, 198, 211, 222, 213, 202, 184, 204,
#        288, 220, 299, 303, 212, 196, 179, 205, 230, 203, 280, 169, 188,
#        178, 175, 166, 163, 168, 165, 189, 162, 215, 193, 176, 191, 174,
# ...

# %%
sns.histplot(data=df,x='average_montly_hours',hue='left')
# Out:
# <Axes: xlabel='average_montly_hours', ylabel='Count'>

# %%
df1=df[df['average_montly_hours']>285]

# %%
fig,axis=plt.subplots(nrows=3,ncols=2,figsize=(16,12))
plt.title("average_montly_hours>285")
sns.countplot(data=df1,x='number_project',hue='left',ax=axis[0,0])
sns.countplot(data=df1,x='time_spend_company',hue='left',ax=axis[0,1])
sns.histplot(data=df1,x='satisfaction_level',hue='left',ax=axis[1,0])
sns.histplot(data=df1,x='last_evaluation',hue='left',ax=axis[1,1])
sns.countplot(data=df1,x='salary',hue='left',ax=axis[2,0])
sns.countplot(data=df1,x='Department',hue='left',ax=axis[2,1])
#'satisfaction_level', 'last_evaluation'
plt.xticks(rotation=90)
plt.show()

# %%
df1['promotion_last_5years'].value_counts()
# Out:
# promotion_last_5years
# 0    235
# 1      3
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df['promotion_last_5years'].value_counts()
# Out:
# promotion_last_5years
# 0    11788
# 1      203
# Name: count, dtype: int64

# %%
<2,3,4, (5,6,7)

# %%
df1=df[df['time_spend_company']>=5]

# %%
df1['promotion_last_5years'].value_counts()
# Out:
# promotion_last_5years
# 0    1833
# 1      53
# Name: count, dtype: int64

# %%
sns.countplot(data=df1,x='promotion_last_5years',hue='left')
# Out:
# <Axes: xlabel='promotion_last_5years', ylabel='count'>

# %%
#1991
#600-> (atleast 5 years, never had promotion)
#df1=df[df['time_spend_company']>=5]

# %%
fig,axis=plt.subplots(nrows=1,ncols=2,figsize=(16,6))
sns.histplot(data=df1,x='satisfaction_level',hue='left',ax=axis[0])
sns.histplot(data=df1,x='last_evaluation',hue='left',ax=axis[1])
plt.show()

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df['Work_accident'].value_counts()
# Out:
# Work_accident
# 0    10141
# 1     1850
# Name: count, dtype: int64

# %%
#
df1=df[df['Work_accident']==1]

# %%
fig,axis=plt.subplots(nrows=1,ncols=2,figsize=(16,6))
sns.histplot(data=df1,x='satisfaction_level',hue='left',ax=axis[0])
sns.histplot(data=df1,x='last_evaluation',hue='left',ax=axis[1])
plt.show()

# %%
df['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
plt.figure(figsize=(16,6))
sns.countplot(data=df,x='Department',hue='left')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
dep_left=df.groupby(['Department','left']).size().reset_index(name='count')
dep_left
# Out:
#      Department  left  count
# 0            IT     0    818
# 1            IT     1    158
# 2         RandD     0    609
# 3         RandD     1     85
# 4    accounting     0    512
# 5    accounting     1    109
# 6            hr     0    488
# 7            hr     1    113
# 8    management     0    384
# 9    management     1     52
# 10    marketing     0    561
# 11    marketing     1    112
# 12  product_mng     0    576
# 13  product_mng     1    110
# 14        sales     0   2689
# 15        sales     1    550
# 16      support     0   1509
# 17      support     1    312
# 18    technical     0   1854
# 19    technical     1    390

# %%
dep_left['Department'].unique()
# Out:
# array(['IT', 'RandD', 'accounting', 'hr', 'management', 'marketing',
#        'product_mng', 'sales', 'support', 'technical'], dtype=object)

# %%
len(df[(df['Department']=='IT')&(df['left']==1)])*100/len(df[df['Department']=='IT'])
# Out:
# 16.188524590163933

# %%
import numpy as np

# %%
np.round(1.9832653,2)
# Out:
# np.float64(1.98)

# %%
for dep in df['Department'].unique():
  attrition=len(df[(df['Department']==dep)&(df['left']==1)])*100/len(df[df['Department']==dep])
  print(f"{dep} attrition: {np.round(attrition,2)}%")
# Out:
# sales attrition: 16.98%
# accounting attrition: 17.55%
# hr attrition: 18.8%
# technical attrition: 17.38%
# support attrition: 17.13%
# management attrition: 11.93%
# IT attrition: 16.19%
# product_mng attrition: 16.03%
# marketing attrition: 16.64%
# RandD attrition: 12.25%

# %%
# https://drive.google.com/file/d/1S-90l8dgmaZuqQL8ulR7qZ4Bu9cc78se/view?usp=sharing
