# %% [markdown]
# ### Introduction to Natural Language Processing (NLP) - Assignment
# #### by Gaurav Singh (grv08singh@gmail.com)

# %%
import numpy as np
import pandas as pd
import re, string
import emoji

import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import TextVectorization
from keras import Sequential
from keras.layers import Dense, Embedding, SpatialDropout1D, LSTM

import nltk
from nltk.corpus import stopwords

import warnings as wr
wr.filterwarnings('ignore')

# %% [markdown]
# #### Problem Statement:
# You are a Data Scientist in a big firm. You have to develop a `deep learning model` to perform `sentiment analysis` on a dataset of `tweets` related to various candidates.
#
# #### Tasks to be Performed:
# ##### 1) Data Loading and Preprocessing:
# * __Load__ the `tweet` data from a `CSV file`.
# * __Filter out__ the relevant columns: `candidate`, `sentiment`, and `text`.
# * __Preprocess__ the text data by __removing__ `stop words`, `punctuation`, converting to `lowercase`, and other cleaning steps.

# %%
nltk.download('stopwords')          #if running for the very first time
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Grv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = (
    pd
    .read_csv("Tweets.csv")[['name','text','airline_sentiment']]
    .drop_duplicates()
    .apply(lambda col : col.str.strip().str.lower())                                 #lowercase
    .assign(text = lambda x : (
        x['text']
        .str.replace("http\S+|www\S+|https\S+|@[a-zA-Z0-9_]+|#|\\d+","",regex=True)  #remove url, nametag, hash symbol, numbers
        .apply(lambda y : " ".join([w for w in y.split() if w not in stop_words]))   #remove stop words
        .apply(lambda y : emoji.replace_emoji(y, ""))
        .str.translate(str.maketrans("","",string.punctuation))                      #remove punctuations
        .str.strip()
        .str.replace("\s+"," ",regex=True)                                           #more than 1 spaces to only 1 space
        
        )
    )
)
for t in df['text']:
    print(t)
# Out:
# said
# plus added commercials experience tacky
# today must mean need take another trip
# really aggressive blast obnoxious entertainment guests faces amp little recourse
# really big bad thing
# seriously would pay flight seats playing really bad thing flying va
# yes nearly every time fly vx “ear worm” won’t go away
# really missed prime opportunity men without hats parody there
# well didnt…but do d
# amazing arrived hour early good me
# know suicide second leading cause death among teens
# lt pretty graphics much better minimal iconography d
# great deal already thinking nd trip amp even gone st trip yet p
# flying fabulous seductive skies again u take stress away travel
# thanks
# sfopdx schedule still mia
# excited first cross country flight lax mco heard nothing great things virgin america daystogo
# flew nyc sfo last week fully sit seat due two large gentleman either side me help
# flying
# know would amazingly awesome bosfll please want fly you
# first fares may three times carriers seats available select
# love graphic
# love hipster innovation feel good brand
# making bosgtlas non stop permanently anytime soon
# guys messed seating reserved seating friends guys gave seat away want free internet
# status match program applied three weeks called emailed response
# happened ur vegan food options least say ur site know able eat anything next hrs fail
# miss me worry together soon
# amazing cant get cold air vents vx noair worstflightever roasted sfotobos
# lax ewr middle seat red eye noob maneuver sendambien andchexmix
# hi bked cool birthday trip you cant add elevate no cause entered middle name flight booking problems
# hours operation club sfo posted online current
# help left expensive headphones flight iad lax today seat a one answering lampf number lax
# awaiting return phone call would prefer use online selfservice option
# great news america could start flights hawaii end year via
# nice rt vibe moodlight takeoff touchdown moodlitmonday sciencebehindtheexperience
# moodlighting way fly best experience ever cool calming moodlitmonday
# done done best airline around hands down
# book flight hawaii
# chat support working site
# view downtown los angeles hollywood sign beyond rain mountains
# hey first time flyer next week excited hard time getting flights added elevate account help
# plz help win bid upgrade flight laxgtsea
# unused ticket moved new city fly fly expires travelhelp
# flights leaving dallas seattle time feb
# elevategold good reason rock
# dream
# wow blew mind
# last night tribute soundofmusic oscars think agree
# entertaining
# flight way supposed take minutes ago website still shows on time in flight thanks
# julie andrews way though impressive
# wish flew atlanta soon
# julie andrews hands down
# flights leaving dallas la february th
# hi excited lgagtdal deal trying book since last week amp page never loads thx
# know it need spotify stat guiltypleasures
# lady gaga amazing
# carrie
# new marketing song let us know think
# julie andrews first lady gaga wowd last night carrie meh
# called weeks ago adding flights elevatethey still shown uphelp
# great go carrieunderwood
# sorry mary martin first
# love three really cant beat classics
# flight dal dca pm tried check could not status please
# heyyyy guyyyys trying get hour someone call please
# hi virgin hold minutes earlier flights la nyc tonight earlier pm
# congrats winning award best deals airline us
# everything fine lost bag
# need change reservation virgin credit card need modify phone waive change fee online
# emailed customer service team let know need tracking number
# hi booked flight need add baggage this
# airline awesome lax loft needs step game dirty tables floors
# worried great ride new plane great crew airlines like this
# awesome flew yall sat morning way correct bill
# watch best student films country feet cmfatfeet
# first time flying all different ratepolicy media bags thanks
# going customer service anyway speak human asap thank you
# happened doom
# cant supp biz traveler like customer service like neverflyvirginforbusiness
# applied member inflight crew teamim interested flightattendant dreampath g
# best whenever begrudgingly use airline delayed late flight
# interesting flying this cancelled flight next four flights plannedneverflyvirginforbusiness
# disappointing experience shared every business traveler meet neverflyvirgin
# i’m trouble adding flight wife booked elevate account help
# cant bring reservation online using flight booking problems code
# random q whats distribution elevate avatars bet kitty disproportionate share
# lt flying va life happens trying change trip jperhi helpva home page let
# site down back up
# you rnp yeah know me
# hi get points elevate account recent flight add flight points account
# like tv interesting video disappointed cancelled flightled flight flights went jfk saturday
# landed lax hour here late flight bag check business travel friendly nomorevirgin
# flight redirected
# me website down btw new website great user experience time another redesign
# cant check add bag website working tried desktop mobile
# let scanned passengers leave plane told someone remove bag st class bin uncomfortable
# phone number cant find call flight reservation
# anyone anything today website useless one answering phone
# trying add boy prince ressie sf thursday lax
# must traveler miss flight late flight check bag missed morning appointments lost business sfolax
# check new music
# hows direct flight fllgtsfo unexpected layover vegas fuel yet peeps next bought vegas flight sneaky
# late flight bag check lost business missed flight apt three people flight exp
# amazing customer service again raeann sf best customerservice virginamerica flying
# called service line hung on awesome sarcasm
# site tripping trying check getting plain text version reluctant enter card info
# scheduled sfo dal flight today changed th due weather looks like flight still on
# getaway deals may oneway lots cool cities cheapflights farecompare
# getaway deals may oneway lots cool cities cheapflights farecompare
# getaway deals may oneway lots cool cities cheapflights farecompare
# getaway deals may oneway lots cool cities cheapflights farecompare
# great week
# come back phl already need take us horrible cold pleasecomeback
# concerned fly plane needs delayed due tech stop
# best airline flown oneasy change reservationhelpful representatives amp comfortable flying experience
# again another rep kicked butt naelah represents team beautifully thank you
# beautiful frontend design right now cool still book ticket bc backend secure
# love team running gate e las tonight waited delayed flight kept things entertaining
# use another browser amp brand reputation built tech response crossbrowser compatible website
# flight flight booking problems site totally down folks problem
# like customer service min delay connecting passengers seems long va
# thanks outstanding nycjfk crew moved mountains get home san francisco tonight
# absolute best team customer service ever every time fly delighted thank you
# provide complimentary upgrades first class available seats
# need change flight thats scheduled hours min wait time phone im calling intern help
# completely awesome experience last month boslas nonstop thanks awesome flight depart time vabeatsjblue
# watch oscars jfkgtsfo flight
# flight cancelled flightled is
# failing customers check process link tsa precheck
# us too terrible airline gave us hotel hotline number said sorry
# flight number sfo cabo san lucas arrived yet
# assistance yesterday u cancelled flightled flight give us hotel hotline shame you
# another delayed flight likingyoulessandless
# need register service dog first class ticket sfo gt dulles phone queue hour longer pls advise
# rock making watch oscars flight redcarpet oscars oscars
# dropped track you
# always xoxo
# cant book seats flights buy even check in creates much anxiety frustrated
# think paying extra bucks rt luggage might afford hiring extra hand lame
# best customer service rep world irmafromdallas takes cake
# find us flt lax sooner midnight monday would great customer service
# please provide status flight cant imagine time web indicates dude weather andor dallas
# amazing staff amp super helpful ran princesshalf spoiled comfort
# paid premium fly across country cancelled flight flight offer check fee upgrade love sad face
# question possible book seat infant giving option want seat him
# always together welcome rt welcome
# flight home dc sunset globe in backtowinter back work refreshed
# understand need dm give answer damaged luggage policy
# mean policy destroyed luggage
# special assistance travel alone w kids infant priority boarding
# thank checking in tickets purchased customer happy
# website ever coming back online
# flight love field sfo definitely cancelled flightled monday february
# flight lga dfw time
# drivers license expired little month fly friday morning using expired license
# problems flight booking problems web site keeps giving error contact phone phone minute wait
# reschedule cancelled flightled flights online change button greyed out
# rang wait minutes book ticket vendor fix site
# got flight we told todaychecked email tomorrow unacceptable
# flight lga cancelled flighted stuck dallas called reschedule told could get flight today
# pairings include red wine white offered redwineisbetter
# website down
# site seems little wonked right now may want look tried two browsers css
# disappointed agent designated silver status check line closed assist pasengers
# plans include austin dallas route topnews arab emirates
# normal receive reply central baggage baggageissues smh
# logan airport waiting checkin flight checkin desk open why
# jump dallasaustin market
# beats eps views takes southwestair va luv investors business daily
# lister show monday
# begin dallasaustin flights april ketr
# congrats got business ewr sfolax fuck fl sfoewr clincher
# applied weeks ago heard back flying week disappointed
# love know policy damaged luggage
# thank follow
# many apologies r worse airlines even respond cudtomers
# shame va making people spend money stranded cities airlines landing jfk reimburse me
# dm
# please flights sjc choice fly southwest vegas
# bad say takes days via confirmation email inquired weeks claim weeks
# flight bos gt las tomorrow cancelled flightled notification wait times hour rebook another airline
# rt you’ve met match got status another airline upgrade restr
# way fly elevate gold
# guys flights cmh
# lot apologies thrown customers seevery sad thanks nothing worst airline ever
# flight stuff wrong nothing it worst flight ever
# issue finding missing item plane help find airport plane headed next
# match americanairlines status cool
# “youve met matchgot status another airline upgrade
# trying book flight guys website let me lose business
# suck
# thanks
# dmd issue persisting
# never recd cancelled flightlation notice left w options fly ps driving la red eye mon w kids
# trying book flight amp site
# flights flying boston tomorrow need home cancelled flightled flight anything
# stink flight cancelled flighted psp jfk notification ability rebook disappointed expected better
# love guys song dancing high school dance revue
# website trying check in
# done thank quick response apparently faster sitting hold
# nervous flight dc lax getting cancelled flightled tomorrow sent dm help me
# cool picture another virginamerica plane wing site
# keep great work
# goodness people field amazing pressure from texas beatstheothers crisis please fly ny
# thanks great flight la boston pilots great job landing snow go back la now seriously
# please get new york area monday afternoon
# thanks much awesome support guys rock
# seats row recline mention website soreback
# flight delayed hours la due mechanical problems handle like pros could tossed us free drink
# cancelled flight flights today precipitation scared of
# twitter team guys killed rescheduling asap thank you
# guys charged reschedule flight cancelled flighted refusing refund it whats deal
# can’t access website safari iphone seems work mac ipad need iphone add passbook
# ipad iphone clicking checkin link email received hrs flight
# mobile site broken shows headerelevateusernumofpointsavailable number points let checkin
# really looking forward flight let know rescheduled diehardvirgin
# cancelled flight flight vx one sec delayed airport next cancelled flightledgonna email call reschedule
# problem link email checkin thanks
# change another airline get dc today able land dc you cost ugh
# looking forward first flight today cancelled flightled along subsequent one
# putting great deals pdx las las pdx show love
# wish afford fly next friday going back home love everything airline
# gonna deal dallas dc deal dc dallas sad
# it’s bug report guys
# hold times call center bit much
# like
# site down help
# best flight attendant ever
# awesome rt watch nominated films feet meetthefleet oscars
# thanks much
# trying reset password email never arrives help
# airline based silicon valley disruption fcmostinnovative incubator s
# nicely done
# i’m looking forward watching oscars flight home tomorrow might even get something bubbly drink
# reason delay departure vx jfk afternoon
# todays flight palm springs ca jfk ny cancelled flightled
# hahaha guys amazing love guys
# sounds like fun
# updates flight jfk gt lax
# spruce moose
# css site right now please fix site unusable
# flight vegas boston today checked online bag count register fix somehow
# classiq luv virgin america greetingz
# hi trying checkin website working tried different browsers problem continues
# thanks great customer service today amp helping get travel sorted out
# thanks guys sweet route rockies airplanemodewason
# love music blasting gate boston waiting flight sanfrancisco could get iced coffee
# passenger d flt assaulted flown trust banned crew filed report
# current bug website shows ‘select departure city’ selecting destination city
# luggage severely dentedmissing wheel coming baggage claim san luggage agent miranda i think help
# thank easy itinerary shift impending weather quick painless amp free
# love see girls inspired become pilots rt free woaw event march abq
# thanks good times back vodkatonics entire flightsfo
# beats expectations shares take santa cruz sentinel
# plans start flying direct dal las
# big lovegratitudempower w werin oscars vipswagbags avalonhollywood
# great job adding little luxuriesaesthetics improve air travel experience thank you keep up
# requested window seat confirmed window got stuck middle seat good way treat silver member
# grand budapest hotel oscarscountdown
# missed next trip
# wtf paid direct flight purpose stop fuel exhausted frequent flier nothing inconvenience
# something wrong website safari iphone
# thanks gate checking baggage full flight dfwlax giving early boarding sweet
# already checked page expired x
# boo refunding seat upgrade fee want buy first place
# shares rise q financial results usa today
# adds pillows instead lieflat seats first class arms race
# see
# way take advantage mayweatherpacquiao
# know flying virgin fight mayweatherpacquiao
# inflight team makes experience amazing
# cutest salt pepper shaker ever think guys cant get better do
# moved seat notice better seat cabin select behind row selected disappointed
# shares q results
# fav airline
# hot female pilot sweet dca sfo
# guys going start flying paris welcome”
# policy flying surgery still waiting answer tell doctor
# already contacted central baggage amp sent dm charging dress lost suitcase help
# thank you
# anything going website getting lot errors past minutes
# think left something plane yesterday callah
# need follow back order dm
# need start flying
# told check airline regulation first contacted you
# checked flight sfo lax amp told atlantic flying club gold get benefits
# husband ordered three drinks via screen never came awesome
# soooo guys going leave seatbelt light flight barely call turbulence
# policy flying surgery
# posts second consecutive fullyear net profit
# funny story website broken missing javascript stylesheets checkin process dislike this
# would love virgin like
# results handily exceed forecasts
# applied position and wondering guys received application
# achieves second year profitability despite revenue pressure
# gives positive outlook sees increased competition
# trying check am ct flight tmm desktop website working some sort caching bug sos
# weather delays gt next weeks jfk bos dca
# check website go airport
# guys know checkin links emails broken
# pilot says expect choppy landing nyc due gusty winds wa temperature degrees amp wthe windchill
# loved it cant wait mondays return flight mostly watch inflight safety video again sorrynotsorry
# lost luggage days ago flight vx lax iad amp calling every day responseplease give back stuff
# flight booking problems section website seems broken chrome might wanna look that
# hi wanted see new routes planned year newark love flying guys hope more
# mean probably inappropriate board but on
# happy spend day together lets this
# saving sanity right now
# missed flight standby work
# understanding helped out thx comps
# brought way across country today see
# thank you absolutely
# looks like broken link assets
# ready lets say together noooo turbulence today
# manage itinerary section website seems broken
# cant check in site looks like every time loads
# u help needs urgent treatment iny old battling cancer could u help flights freyasfund
# may start service hawaii sanfrancisco year biztravel
# carriers less half price round trip fare stunned
# wtf happening pdx late flight march one way sfo
# add dtw sold
# free drinks flight back free promo
# thanks
# momma made it
# please contact portfolio left flight vx jfk sfo tonite seat am need returned call
# help flight jkf tonight seat c left portfolio need back
# seattle bound wifey got duffle vday keeper holla
# luggage gone filed paperwork promised callemail still resolution response central luggage
# debbie baldwin gave rockstar performance safety demo evening vx lassfo bestcrew sherocks
# thanks
# thanks taking care flight rockstars travel
# thanks lovely soft views travel san sfo
# requested mileage challenge status several weeks ago online heard back get help this
# trying book tickets nyc facing super fun broken styling worry keep trying
# many thanks follow ourprincess freyasfund usa bandie looking help
# nice lofty view silverstatus
# applied status match feb got confirmation email day still news though guys dropped ball late flightly
# new go airline
# help ourprincess need help usa
# adore you looking forward flight austin two weeks
# glad mentioned took first virgin flight years back transformative experience
# flight booking problems flight uphold status match taxes ticket count earned status points statusmatch virginamerica
# trying checkinbut looks like site down
# spending birthday night you daldca get home
# sent couple messages email provided avail try next year cheers
# first time flying virgin went sanfrancisco thanks smooth ride easily new fav airline
# seriously though direct flights sfofll may
# fine already done purchase try it go way go back
# really experience hoping ws forced check small carry on w nothing empty cabin space board
# wjere luggage slow lax
# jump dallas austin market
# spoke representative offered solution loyal customer flies well
# deeply disappointed birthday promo applied trip booked mere days received email
# happened direct flights sfofll looking may see connecting help dontdothistome
# help left blazer in kooples jacket bag rd row second seat right gate lax flight sfo
# partners checkout mobile payment method help boost mobile conversion rates etailwest payments visa
# promoting product all problem southwest recommend noneother best
# love guys pls get direct routes las aus
# would like help flights please
# bruh “ turn what vxsafetydance”
# course work obsessed entire virgin family
# ok first time flying tonight
# digging swanky pink mood lighting flight nyc sfo needs cabaret singer think it
# done need receipt asap could please help
# embossed badges patches superior ones currently using
# vx jfk la dirty plane standards
# flight vx headed la jfk dirtiest va plane ever on sad great airline
# got squared away someone picked soon tweeted tweeted sooner
# avis rental continue button work website book car tried times phone sucks
# delayed to
# currently minute hold cust service need anything add lap child reservation
# adds pillows instead lieflat seats first class arms race
# “ course fun celebrating” thanks happy chinese new year
# flight booking problems last second flight next week sfo san chance want gift promo code since love guys
# comenity bank joke please change nothing constant problems bank
# did dm u also add me
# grandma ellas th would lt bday greeting flight crew stewardess eastern airlines
# bought tix atx dallas route thanks adding that love yr airline amp yr website best transactional site ever
# anytime sugafly
# gave credit late flight flight yesterday great service thats wow moment unexpected gesture
# need receipt flight change send one
# submitted status match request back still haven’t heard i’m flying monday look accelerate
# safety video loved first cross country flight livewelltraveled sytycd
# look fat me looks yummy
# ceo says southwest amp jetblue strayed low cost model
# brilliant brisk boston cue vx
# atlantic ploughs lone furrow middleeast
# atlantic ploughs lone furrow middleeast
# atlantic ploughs lone furrow middleeast
# omg omg nonstop dallas austin virgin
# planes really pretty thought u know that
# flying hawaii
# pulling hair trying book flight u site work iphone ipaddont computer help
# thank
# get help support ticket days incident thank you
# good home texas moodlighting
# cannot even open laptop seat c paid premium this let here
# seat c cannot even open laptop paid extra seat
# guys starting flights end month guess i’m still road tripping feb …
# thanks that needing way make austin trips dca come through
# announced new route austin wfares way
# really sprint thought guys kewl
# cool never ur planes will
# dollar laxlas fares
# great well deserved
# fyi infocom email address say contact password reset emails exist emails bounce
# status match weeks gone newsflt next week hope flt count towards requirement cust svc help
# website sucks donkey dicks thought know best
# still develop app favorite airline
# crap channels pay watch uk tv
# got it set thanks
# as channel year
# thing see passbook virgin mobile mexico integrate
# giants virgin america match made heaven
# thank goodness also see friday nwkgtsf boom
# come iphone app still using making waste paper
# back seat entertainment system accept credit cards apostrophe surname apostrophefail
# vx use lga slots instead today adding aus makes less likely
# helping step game tindertips tinderchamp
# luv ur people product thing u charge herbal tea black tea caffeine drinker
# thank you see yall soon excited see expansion destinations spread wings
# announces new nonstop connecting amp intro
# adds austindallas love field route
# sad learn longer fly sfo gt phl hope returns
# tweet cancelled flightchng fee flight rebook one affiliates so afiliates
# incredible customer service ever experienced refreshing
# now see virginamerica come philadelphia phl
# dreaming really open route dallas austin mean houston might next
# omg finally
# start xweekly flights dallas austin apr avgeek
# nice see expanding texas forget us sandiego would love see flights here
# kinda sucked earphone jack work flight may want look future passengers
# poor experience first computer problem seat malfunction stuck missing meeting san diego
# battle route via
# thankyou dalaus route makes day
# awesome deals dalaus way
# miss nerdbird san jose
# love it taking backyard consumers win biz competes
# ​ flying love austin now excellent news
# make every vx plane nerdbird austin one getting nerd love
# please add frequency pdx portland
# congrats vx new route
# tried that offered charge additional k new ticket stranded thurs st time last time
# u help flights get old battling cancer needs treatment
# never bad experience before one took cake extortion carry items well
# spend hours worrying items carryon would brokenstolen since carry plane lock bag
# group e told room bins got plane room least bags row
# thanks making flight lax jfk nightmare forcing check carry bag gate
# lots flights book site working phone waiting minutes
# flight artisanal cheese wine pairing
# virgin america fly direct seattle nyc boston
# thats classy
# sure lot jfklhr flights go lot faster mph strong tailwind
# tminus minutes elevate silver upgrade window opens freeneversucks
# save tomorrow am
# taking years fly home dallas get shit together
# club virgin bumping new york
# would rough trip luckily virginamerica flight weather
# thestarter
# please come minneapolis st paul
# yes fyi bff
# another perfect flight come planes sun visors stay down carriers make raise them
# nice rt man steel might faster wifi – saying sciencebehindtheexperience
# love dancing little richard cool beans
# don’t use passbook still love though lt i’ll use email future
# thanks free birthday points yall right me
# application ios looking saw virgin mexico lt
# man steel flies cities thoughand frequency too
# thanks much sharing added site
# good point
# heard virgin mobile hotspot
# got cheese plate flights too
# flights
# dad segway best part whole infographic
# plans short haul airline europe would defiantly fly guys
# wifi better seating
# come abc one network channels have
# started flight scolding using overhead bin offered person seated next me
# great return calls day after ask more myvxexperience
# airlines cancelled flighting flights bos helping customers get home virgin saying good luck
# dear virgin customer stranded sf days amp cost least accommodate you
# use next airline commercial lol
# grouping virgin others now bos weather exposed actual cus serv model never flight booking problems virgin again
# one travelers affected boston storm shocked virgins complete apathy toward customers
# umm reason is someone different contact or contact me get definitive answer
# trying make change advance not hours prior…tried online earlier wanted change fees
# loyal driving nyc pa fly virgin since cut philly flights
# way change main cabin main cabin select on flight without paying change fee penalty
# guys perfect always lt wervirgin
# thanks yall best customer service left industry
# give silver status months
# really wish fly fargo fares amazings
# mood lighting point reclining seat kickin feet
# flight scheduled pm departure still says time plane gate update long delay
# group got cancelled flightlation fees waived cant ticket booked reps help either
# sign bonuses enroll elevate
# got pm newark home la folks ewr incredible letsgohome
# morning question regarding elevate points amp flights dm you
# still waiting see
# wondering guys recieved dm able potentially respond asap
# flying lax sfo looking awesome movie lineup actually wish long haul
# “ book town fares way restr
# thanks
# thanks taking care mr happy customer
# still refund word via dm please resolve issue cancelled flightled flight useless assistants trip
# delayed due lack crew delayed theres long line deicing still need improve service united
# thanks filled out hows luck this common
# eriord express connections hugely popular could eriewr hop
# even international flight glasgow us orlando newark mins
# think boarded flight au early think so
# understand tough way get airport wo serious risk accident steep price
# gate agent hooked alternate flights way prevent constant issues would rock
# flying glamco weeks long airport departure international domestic ta
# thanks
# thanks ticket
# not law policy
# worst nonrefundable first class tickets oh select globalfc system auto selects economy wupgrade
# buy tix days flight cant transfer tix flawed security logic flawed customer service
# start claim weeks unrealistic really supposed go long car seat childridiculous
# follow please airline beautifull
# dont sure united info system
# car seat lost reimburse new one pair shoes necessity child
# submitted response link sent
# yes david allan send email number kmmvlkm case
# totally sucks cousin worked phl said
# wanted let know wonderful rosetta gate agent working flight dan ase let know wasappreciated
# yes paper voucher got january th
# beginning feb called united said would send another voucher mail never got anything tiredofwaiting
# internet great thing emailing executives company maybe respond timely manner
# need use chase united club pass yr old son come pass
# suppose number
# thats weak see ya hey
# flew back w company since united didnt earlier flight
# lost voucher given miami aeroport jan use it
# trying book awards september need flights show even w many award seats availab
# sure did drive total hours get bag like explain debacle one wants talk me
# gee thats like almost caring ppl think int trusted adult w daughter
# see told repeatedly pilot late flight kept getting late flightr boarded defibrillator issue
# preferred security line anymore tsa precheck pull partner flight platinum spoiled
# newarkliberty airport need indicate different gates terminals aampc flyingainteasy
# yes please newly married trying update last name preexisting international flight seems easy but
# united refuse reissue lost voucher plane take due mechanics badcustomerservice
# also run instructed do shattered computer
# yes agents last minutes one agents rude thankfully ladan nice
# thats right overnight miami
# clients hr layover iah during day claim amp recheck luggage taken care of
# trying find loaner seat new used used car seat illegal according safety regulations
# dmed details
# iah charlotte baggage claim rep latrice h customerservice non existent ignored customer inappropriately touched customer
# kewl also let know overhead bin row inop love good abbreve
# thanks helpgot need issue guess sit awhile longer
# would loved respond website saw really long form business new seats bad
# refund flight vouchers another flight different airline expense today hour drive inconvenient
# received call back daysits infant car seat supposed go anywhere child
# thanks concern contact customer care upon return australia
# well sitting ground on time waiting gateagain tiredofthis
# airport snow removal method keep good work folks cessnas become s
# no need guys book planes concern travel someone else moving forward
# measly ecertificate appreciate loyal customers wait hrs tarmac ua unacceptable
# email addressusername signon available while
# thank that able claim interim expenses cost stuff me
# rude rude
# cant get boarding pass austrian airlines codeshare flight rebook incls hour layover amp stuck outside sec
# i received flights united truly breaks guitars unitedbreaksguitars wantmymoneyback
# flew telaviv paid third suitcase even make plane besides impolite service
# bag still colo springs disabled search unfamiliar airport look bag good outcome
# shame theres flex tickets transfer rules even calling neurosurgery icu enough
# no denver said handle baggage made colo springs gave number call help either
# guys need serious training customer service many better options put way guys handle ur mistakes
# ord dca
# found problem avoided like plague told we cant find supervisor
# zccu cancelled flight flight h advance need connect flight reschedule link helping help gf waited months see me
# flying
# addition first flight delayed hour arriving destination hrs late flight
# cancelled flighted flight rebook us added flight drive denver kcthanks
# announcement pre boarding addresses mobility disability requires travel lot stuff preboard
# flew united last month experience awesome
# travel booked thru united group dept okc ticket agent less willing help connection lax
# v upset disability services told one employees carrying medical equipment rude
# thnx quick reply think assist intl grp put considerable inconvenience today
# wont transfer flight ticket accompany yr old whos active military mom emergency brain surgery wow
# weeks late flightr still received miles mileageplus gift card starbucks card handed over
# k always hoping improvement
# yet complained guy checked luggage throwing bags around unfortunate coincidence hope
# okc ticket agent roger mclarrensp less helpful intl group travel problems cant find supervisor help
# mobile apps need construction ground os category expensive get right
# another fail united ticket agents okc less helpful could care less problems american come
# also working wc coach good thing bird landed ahead schedule use wc stat
# os controlled rather app new
# sent email customer care telling may break sincerely hope help me
# silly flying delta today united club staff attendants surly unhelpful always seem bothered pesky folk
# phone number cant find call flight reservation
# well cant fix missing buddies th bday negligence attempt make it
# believe help customer service couldnt like said want number someone fix did
# helped baggage service desk said bc tsa screening fll bags made bag ewr
# mobile boarding pass disappeared phone standing line board second time week hmm
# record rozana newark lovely helpful choosekind
# last nights ordlga
# thx update
# thank
# dm nuts
# explain eager flight attendant trying ask vision guide dog
# whats point asking details servicedog book flight crew read them continued
# tried one available bogota everyone rude houston stuck hours guys
# worstunitedflightsever ua las iad mechanical problems took land fix delayed wtfodds
# despite bag making newark good informative email tracking updates help
# whats going ua outbound flight last thurs delayed hrs long delay be worstunitedflightsever
# worstunitedflightsever ua iad las mechanical problems switched aircraft delayed hours
# crashed trying check in
# wow deal again plus seats available easy change make customer happy
# thanks info already knew
# airline trouble winter amp getting good customer service contact negotiate resolutions you
# logan boarding gong show due lax carry enforcement bins full coats room bags u need better system
# thank you
# blackmailed paying £ extra return ticket nullified san francisco airport terrible service rep scam
# email address reach long dm
# disappointed u didnt honor credit given ur mistakes taking business elsewhere out
# ua still waiting supposed depart
# credit last trip never came mail
# ok months waiting hear airline gave quite bit days requested terrible service
# process ever end still waiting reply since months pathetic customerservice
# whats going website flight booking problems three tickets today booted system umpteen times
# get account number website says email unavailable
# need book two one ways order fly unaccompanied minor
# received bag last night still missing one
# need upgrade seats too even economy plus like sitting concrete bench
# pls help baby hannah get life saving surgeries requiresshe needs helppls donatert
# bet wont honour them like mine ey
# nd flight also delayed pilots boarded sit here scheduling
# guess thats much ask huh
# hard stay upset someone least try show remorse
# way simple apology goes long way even hollow one obvious care wellbeing
# one time thing either shocking pattern repeated neglect disrespect
# fingers crossed amp intact disappointed experience actually saying enjoyed using
# incredibly easy fix would rather stay comfort zone get forced mine
# july zero excuses this outofdate system causes problems like this
# everyone around us sitting friends family members booked tickets october december bought
# sure talking about going nonstop flights sna sfo sfo ewr
# moving talk service
# please good weekend
# asked legitimate question systemwide vs localized problems got back unrelate flightd copypaste better
# time call need skis go airport get them faith united
# see guys again amazing one company continually makes mistakes yet fails held accountable error
# tourist wonder super tides tide century french uk coasts
# yeah sorry theres always problem united international reputation problems
# yall probably work that
# again maybe would care hear went whoever listens issues caused
# wonder sharing fb insta would produce number characters really limits story telling
# telling number call left airport negligent pilot staff
# could email resent doesnt appear arrived
# yes please trying get pop newark now
# follow order dmcome
# united coupon make broken entertainment system hour flight seriously ridiculousness learncustomerservice
# drop bag overnight amp leaving week supposed hold bag
# dm details still response book today
# know probably way get cheaper airfare ticket flight leaving hours
# someone please explain process happens property found plane passengers leave heathrow
# able dm confirmation number
# sent message let know got it twitterliterate also really going stuck hrs
# unhappy response complaint emailed nd feb ref awful customer service
# dm work do
# private jet would cool work try
# given option using united travelbank recent flight booking problems help using recouping funds thanks
# common keep paper work ready delay flightsand meetings
# yulord
# yep thats correct got email flight cancelled flightled matter flight atl delayed thx
# k problem getting fll iah sent dm making connection please let know
# done done
# thanks sent
# grounded montreal ua missing connection ua st louis helpdo private jet me
# frustrated nervous this
# ones make difficult me
# child someone issue flying prepares ahead time reduce distress caused planes
# get cancelled flightled hours take off
# always happens guys makes traveling incredibly stressful uncomfortable good business you
# someone severe anxiety one person help next him
# seeking go client bc u cant get need refund filled form confident works past indication
# thnx response bot seems improvement could easily attained st class service really worth
# unrivalled access california flights us uk airports nonstop onestop connections yearround
# booked award tix thaiairways seeing conf them united flight booking problems get get thai me
# luckily made flights time disappointed lack communication
# checking see flight atlord got cancelled flighted
# service far horrid wanted end trip high note guess thats option
# booked flight home months ago requested seats together fiancée i got middle seats unacceptable
# guys horrible
# thnx info
# pay wifi international business ticket pennypincher
# ok top things off lost luggage could get worse unitedairlines
# kudos cancelled flightling flights dfw morning united usually first panic
# luggage broken youcouldntmakethis brokenwheel
# flight dfw ord currently ontime see advisory dfw may affected weather
# maybe one day one quoted
# flight delayedno one remembered turn heat flight leaving ordseriously
# another awesome new plane flight extremely nice captain steve connolly
# speak real person get resolved politely efficiently
# filed refund claim told charge dm disputed bank hence would like
# bags make flight iad second day without clothes pretty inconvenient pretty curious unitedairlines
# every united flight saipan guam adventure never know s old plane operational
# hence asking customer service phone number speak real person get sorted
# bags leave washington yet would convenient seeing left day ago unitedairlines lostluggage
# flying st class one leg chicago long flight china still able use lounge chicago
# according dms owed refund please may provided contact number go bank file claim
# hours ago need work bag make hotel time need go elsewhere
# okay thank
# filed claim way calling updates another way this
# pls properly train agents requested speak k customer service amp transferred dead end even open hr
# thanks remembering load bag onto connecting flight oh wait forgot iceland fun clothes
# thank cheese platter abundance entertainment options time flew by
# customer service atrocious disrupted travel plans lost luggage impossible talk human
# terminal mia food open esp flights am two hours early like recommended cant eat
# ua flight currently stuck portland missed ride hour delay getmartyhome
# responded various requests contact numbers anyone know uk customer service number unitedairlines
# looking getting bags lusaka
# could update suitcase please online phone tracking told nothing told back yesterday
# thank you trying two days set up
# last thing u guys charging drinks transatlantic flight
# lhr arrival lounge fail waited mins shower left find hotel u know many passengers u carry planning
# luck finalizing reservation dmd information you please let know else need want confirm asap thx
# completed form doubt use ua care day vacation sure ua feel responsibility that
# definitely compliment really thought bag lost sent another airport end happy customer
# thanx much followed emailed ticket voucher unitedairlines care
# definitely trip remember ewrsti second season first seat pays loyal
# nope told us time go home sleep airport even though assured us would get room
# keep updated let know bags make flight jburg
# back expensive holiday worked year pay for ruined want compensation amp original case back
# thanks united understand that would actually like bag back done it also wants money
# frankly worse customer service ever problems happen deal defines company never united
# still valid flight seems strange delay late flight inbound crew hours now plane already here
# thanks lack help canned response k desk
# bad ua another unforeseeable operational issue return flight
# would like know whats going current flight lands
# pay luggage delivered arrive wait additional days delivery
# hotels people feel like held hostage someone boarding passes cant leave fail
# one great airline
# outbound bags lbs bags returning home bag lbs logic why writing machine human help required
# like hear poor experience please share details wour customer care team
# cancelled flightn left us fend flt came late flight getting runaround hrs employee blaming previous
# local united number malaysia local united airlines kuala lumpur kul
# okay asem find luggage
# agent met us gate said issues wdelays ua would taken online
# send urgent message via eservicecom bgkwm narayanan please respond asap also local united tel kul
# thanks guys getting anytime soon
# not lady one phone says tel aviv tel aviv united says newark one knows nothing
# “ see do kn” running plane running thanks help
# yes still answers many luggage days unacceptable
# going you nothing like always
# sent feedback thank you
# plus food taxis
# offering us rooms people fail
# people getting pretty tired action solving problem plus missing day vacation skiing
# bright side would keeping promise made me hope good night thanks
# yes do
# take back comment team working hard help us far solution hotel food anything fail
# arriving two hours late flight clt sitting tarmac move plane gate unhappy customer
# airlines absolute worst idea doing neveragain unitedairlines
# thanks might want fix line our customer care team currently responding inquiries within business days
# flew united aus austin bergstrom cancun intl best flight ever s big small
# frustrating frequent flyer loyal since continental upgrade equals paying times top purchase ticket
# deep vein thrombosis
# worse cant figure pack plane screws connectns claims hotl rooms san fran stranded pax way go
# passengers hour delayed flight left hotel end night hou airport wtf
# hey flight iah pos leave late flight one back iah early rather get pos earlier
# lost bag process broken agent promised call amp hold bag found waking w delivery fail
# people counter helpful see nobody there flight austin still sitting here
# unfortunately still tarmac definitely missing ride gonnabealongnight
# “ regret hear this please let us know need assistance kn” finally able secure seat thx
# time check open flight ua manchester newark today
# good know open closed doors premier passengers safety briefings delayed flights annoyed
# dm sent
# yea get phoenix already delays day people bullshit
# consolation staff stellar hour delays encountered every one flights
# flight ua gate b tell ray somehow made flight iah wait one
# thats unfortunate xmas gift looks like razor ripped right front pocket picture
# thanks asking
# lost bags cancelled flightled flights delhi call centers poor united staff spread thin stressed name it
# yes make mistake less absurd change fact inconveniently missing luggage tonight
# constantly challenges upgrades amp charges order prevent dvt pay addtl
# ord waited min crew members left gate items came flight attendant sarcastically said good luck walked away
# follow back please happily dm link rather share travel plans publicly
# too
# favorite airline
# seriously fail making strangers share room
# nah
# needed asap make todays flight
# agent split reservation cant cancelled flight refund credit wks
# vacations going ruined w days rain change fee us nearly cost original flight help
# sent message let know asap
# would make share room
# tried calling too w min phn wait means miss options anyway
# ask guys flight bwi wait us get delayed flight san diego pretty please
# still waiting find rep working hard upset wait tomorrow pm get mammoth
# early flt think call appropriate yes reviewed nada avail next day expect full refund
# understand thanks
# ask call get fixed tweeting bs questions stall makes things worse phone number please
# yo yo yo stuck tarmac hours going miss ride help please helpimstuck united
# highly unprofessional overbook flight seats ampfeel rearrange schedule mismanagement
# well considering every agent claimed unable help everything else waste time hear call corp
# man cant wait book ticket now thanks jp life sabe
# ice totally understand large number us facing hours time overnight cancelled flightations seems like
# flt cancelled flightled get email am happened courtesy phn call book diff airline amp city
# tag numbers lets find bags
# better train support staff appropriate decorum consider revisiting terrible provide death certificate policy
# well bar set low guys really good apology game change u guys learn
# post disappointment frequent united flyer simple bad apple spoil bunch
# guys continue impress houston
# way making phones calls need handle via twitteremailweb thank you
# please help ethiopia adopting two year old child existing confirmation need add child reservation
# questionare onboad volt outlets planes so where
# website deserves new design html ftw
# thanks effing holidays missing full day skiing due baggage teams incompetence
# twitter letting dm you
# hope
# agent helps person front me finishes walks away guy behind shocked am
# connection ord exact plane again checked carryon apparently taken amp left chicago pretty ridiculous
# encouraged cpap tonight
# yes file claim soon carousel stopped without bag it got email found sched delivery
# idea monitor mileage members travel patterns enough know change jobslose statusand make transition easier
# delay dencle manually enter baggage tags really worst cust service day ker friendlyskies
# tell us flight delayed tell us time min spare say delayed unless sure
# yes lusaka zambia guess bags never made plane iad
# flight voucher
# late flight denver late flight newarklets even get disaster checking bags unacceptable
# let down think ever flown problems worst airline period
# yes filed claim amp hope receive luggage am ridiculous purchase items go sleep amp reimbursement
# ua ordlhr bags loaded min late flight frigid air cabin plane feels like falling apart upgrade long haul fleet
# flight attendant never served beverage tea checked me gives ua notcool
# load balancing system apparently systemwide major impact united airlines flights cyberattack
# unscheduled refueling stop missing connecting flights r home n looking ward bed big pbampj sandwich
# spent hundreds rectify situation guys go quiet
# ua sitting ewr nearly hour sked pilot says computers clue leave help
# thats it ends there come on traveled literally extra day half this
# made upgrade list fly st tomorrow for min first time ever statusmatchpaidoff
# refunded us vacation get free room night make making us sleep dia
# thanks reminder fun ride
# received luggage also looked left snow arrived asking people refunded
# updated aircraft wifi device entertainment outlets get it charge devices
# one scan inside plane asked people line around plane going
# gate changes two delays even crew thinks airline sucks
# frustrated wasted days due equipment failures
# computers stopped giving updates took flight info app thats ridiculous keep people updated
# soooo days offered response assume poor treatment gate agents norm now
# terrific many thanks looking forward back ua tomorrow great flight vancouver
# calls resulted hrs hold time amp day wait check suspect code share fare nothing investigated—my time wasted
# taken weeks cust care respond case requesting refund wifi working get update
# appreciate efforts getting home
# thats correct—ive spent hours trying book online receive error clicking final purchase button
# today finest could prevented one gate agent advising passengers
# real deal delay flight ua denver vegas
# ...
# flight tomorrow idea rescheduled cant fix online talk agent yet one answers
# kidding think done that called dozens times amp tells call back amp hangs up
# did expect response fiscal year calendar year never
# still waiting bags flight yesterday first class passenger happy service
# aa time awesome flight great job american
# understand waiting hours callback exec plat line call dropped agent could least try
# refused unload luggage stuck freezing weather wo cold weather clothes
# thats asked looking change flight booking problems help
# service horrible cant get straight answer ground agents
# flight miami dallas monday rescheduled tuesday
# yes service guc sucks gate agent pushed passenger rude everyone since got here
# den gt dfw want ticketed new flight refunded cancelled flighted flight
# days bags amazing way neglect customers
# worst airline ever stranded hours hour delay flight last night
# email address send issue to guys screwed rebooked flight wrong day please help
# issue requires bit tweet explain y’all email
# pls help seriously beyond ridiculous
# please call us back rebook need get back columbus please help
# rebooked tomorrow morning never sure see tomorrow morning
# still waiting call backattempt hour cant put hold online tix within seven day window
# seats gvn away strangers chicago rented van drove toledo help offer hotel
# gold elite loyalty customercant count hometown preferred airline right bummed
# please call us back rebook cant through need get columbus
# flight dca need change asap help cant get
# flight cancelled flightled call accepting calls reschedule flight
# jacquelyn charlotte denied compensation cancelled flighted due plane malfunction well within control
# flight first flight
# always love opening upgrade email
# called executive platinum desk got two hour call back time hrs late flightr still call still stuck chicago
# need order special meal cant reach aa hold hours
# two delayed flights today weather relate flightd keep good work
# two hours late flightr still waiting callback need reschedule flight hopefully late flightr one tomo cancelled flighted
# take one reps different gate rude asked assistance thanks though
# flt cancelled flighted rescheduled bad time tried hrs website states cant onlineuseless website help
# still stucked airport aadelay aa
# flight dallas grand junction amazingflightcrew
# redirect flight without telling me service abysmal
# really american airlines service las vegas shocking absolute jokers take reputation seriously
# one received text alerts automated calls anything either literally information happening
# aftr hrs bng held hstg mia bc aa refsd get med bags bag fnd aa refsd fix tkts cnceld said fly
# downloaded app iphone notice drink coupon nothing displayed getting ready fly
# reservation system even let us leave phone way fix rebooked wrong day
# yep good make flight mci wait tick
# got minutes takeoff time anyone wandered address line people
# rebooked tomorrow failed put dl flight today despite asking available seat dl still available
# st leg flight nyc tomorrow cancelled flightled make hold hrs may miss chance back home
# also one single person counter answering questions plane full confused people staff all
# thats complete cop out u ask issues are nothing it supposed sort situation now
# fcuk you shit service got fans
# flight tomorrow already cancelled flightled now
# thank you cant get flight hold cancelled flights
# get person
# rebook wrong day phone system says cant handle volume hangs me
# look cabin crew vacancies
# prime ticketed seat get switched aa sure whats going here
# hi
# cannot talk agents keep getting hung crazy
# cancelled flights flight send email text call stranded louisville
# hi cancelled flightled flight back us take call supposed do
# got rebooked us airways guys flight got work help would appreciated
# hold mins used call back service agent call put hold foreveranyone there
# upgrade with cash main cabin extra buying aadvantage mileage saver using miles cant seem it
# expect that
# flights tomorrow cancelled flighted cant anything online cant get phone help
# tell luggage stayed inside plane look video
# yeah lot questions number one dare
# hi guys checking usaa jfk phx renewed admirals club today
# hey guys dmed question mile upgrades post earning hope use tomorrow
# tried cant get through
# booked wrong flight pe desk wait hours
# think tried multiple times status bag yesterday disgusted
# thnkx bt dont help need go way way get need u charge sux neveragain
# get amp appreciate that many problems last year flying guys pretty aggravating
# sure would bother agent airport didnt help amp nobody phone would ticket cancelled flightled reason
# help needed complaint ticketed passenger available seats scheduled leave late flightr today
# leave luggage baggage claim without previous information thats deal
# hours answered call
# somehow dfw mia got bumped b way g whats that
# americanairlines hr wait bags taste worlds largest airline heaven help aviation
# late flight again again crew
# fantastic support twitter team appreciate it thanks again
# hung many times trying cal crazy
# thats quite impressive list fees
# buy it woody making much worse understaffing rudeness prerookie mistakes
# run engine troubleshoot issue boarding plane another plane aa miatoiah
# “ russ please contact reservations reflight booking problems options” good luck that
# flight cancelled flightled guys help
# changed flight bna ahead weather slammed cost diff no weather advisoryreally
# itinerary ewr dallas la cancelled flightled flight money find way get ewr
# hour baggage carousel still luggage nail coffin
# nicest people ever flight chicagothanks david deane amp norma sedholm making feel comfortable
# cant get thru phone use credit thats expire frustrated aacom
# next lax jfk flight today
# appreciate update also appreciated pilots effort explain us now accurate authoritative comms vital
# one agent helping stagnant line almost customers super
# bad weather surprise doubletriple staff hand handle calls way treat customers
# all plane didn’t land identical worse conditions grk according metars
# flight cancelled flighted lax tomorrow due connection dfw help please go orange burbank
# first pilot catering
# also reservations teams fault bad topdown decision feel bad reservations social media teams
# would like refund flight delayed flight times feel like making fun us
# submitted complaint via link dec amp followed jan never heard back badcustomerservice
# greatest newark gate agents ever david deane norma sedholm luz calderon made feel like king americanairlines
# flights cancelled flightled cant get desk nothing showing online reservation do
# point pic reps struggle merger much imagine public
# flight ewr stop dallas la need la tonight
# flying ft lauderdale fl seattle wa want honor flight
# able get hold system kept kicking main menu
# seattle checkin desk servicing full service line desks servicing priority full srvc wait minutes customer svc fail
# hey tried calling customer service told theres hour wait past hours thanks suck
# since leaving tomorrow miami one thing right deliver bags airport
# yet receive assistance one agents securing new connection many miss work tomorrow
# saying call center understaffed
# trying change frm aa lax am monday morning aa lax fat flight aa helpaa
# flights columbus ohio dallas texas cancelled flighted
# mind aa point twitter acct form letters characters less
# many missed connections already bc delayed flight finally board soon
# flt dfw fat d rebook flight tonight cant get phone
# important morning would seat wife together allow choose seats flight booking problems
# dont believe it impossible agents get update delivery company since yesterday
# yet plenty available aa agents gates nearby say unable help customers flight
# personal touch known for aa cool perks blaming understaffing weather hr hold times
# waiting line hour san antonio barely moved amp two agents front amp least behind
# return flight scheduled wednesday aa believe thanks help
# neglected mention fee per ticket medical reason still jump thru hoops
# i attempt hour calling put hold feeling confident ever get through
# bought ticket two days team share data needed get next meeting
# thanks response know fault im ord hungry want stop
# cut it put flt tomorrow
# nah u boofin u dont talk like humans know respond like u actually brain dont want customer relations
# transportation going city getting ny sometime wed sorry thats gonna cut
# you one thing tried avoid thank sending baggage claim
# flt tom recd notification going airport
# one book ticket online put hold require pay ticket
# help reservation cant get phone
# ask people left behind miami airport guys could wait minutes
# anything get aa moving almost hrs hundreds jfk upset tired want get ba
# insane treatment customers
# help need speak live agent lose online reservation held
# no jfk sort guess things out small airport whatever
# let employees treat loyal customers attackingbabymomma crazinessintherockies
# mad love nyc
# thanks forcing check in carry luggage exactly spent extra money travel size toiletries
# updated screens people would know late flightst info good bad work because
# missing full days work thanks guys
# trying find flight dfw hou tonight exec platinum desk calling back online info clear
# cant even get phone reservations team system automatically disconnects us
# flight cancelled flighted rebooked agent made mistake booked wrong date trying get via phone hours
# no american simple call back info new flight basic customer service
# looked told guatemala last night record anywhere today need clothing work tomorrow
# cool canned response nah think keep tweeting everyone mentions aa twitter could dm me though
# please fix mobile desktop site allow canadians select passenger checking in thanks
# tried ringing told try late flightr supposed leaving hour
# guys amazing job today know it’s hard thanks kate appleton hard work reflight booking problems friends me
# cover rental car refund ticket gladly drive hrs home stuck till tues
# neglected mention fee per ticket medical reason still jump thru hoops
# yes would like refund
# realistic make minute domestic international transfer jfk non us citizen
# eliza amp cheated u amp lovely flight back lots
# hope like photo
# weather bad folks try extra hard communicateor load bags onto flight oranything
# mechanical issue evidence points idea it’s ils cll fault weather
# sorry in like general way sorry incompetenceunderstaffing compounding weather issues
# please help us get home tomorrow
# bad theres only like people team then next level unreal
# real life response customer service issue seriously keep trying call us eh might work
# fix engine flight aaso spend night airport fly home tomorrow
# make sure remember load bags onto plane cancelled flight flight forget
# real life aa like real life emailingcallingdming people inconvenienced
# hey yesterday im still hold
# weather unavoidable understaffing controllable
# late flight boarded waiting min wtf
# get personal response apology crews forgotten load baggage onto flight
# flts jfk cancelled flightled thx ur agent sfo im rebooked ua get name awesome twitterhug shesaidrun
# know hour got live person messes arrival car plans two airports costing us more
# cant get ahold aadvantage reservations need ticket reservation cancelled flights soon help
# also told agents issues arent prob k fine get it compassion others dealing wthis
# whats status dfw ticket agent gate rude unhelpful
# spoken like idiot ok need deal w esp travel experience
# trying switch flight aa currently aa am monday morn aa help me
# really hope departs said catering service wasnt available see next plane nthin
# understand weather fault ur cs reps atrocious happy evr fly w u again
# left orlando nd line standby land th priority members get first available seats awesome
# respond dm tweeted canned tweet telling everyone else
# dmed aa amp phone amp cant someone call me point response resolve anything
# guys email address put next available flight ohare
# eagle always late flight
# never trips airline ever natl intl ever experienced anything like this
# call center let wait hold would happily do seriously supposed keep calling great
# half hour late flight leaving dfwno attempt explanation
# flight tomorrow got cancelled flightled need find alternative get dallas please help
# minutes flight okc make us wait minutes cause gate empty epicfail poorplanning
# seems like queue times high q waiting agent almost hourflight got cancelled flightled
# nah horrible dining options outside club luckily manuel admirals make bloody mary
# earlier flights sapgtmia amp mia gt new york lga currently booked flights
# hold times disconnections excuse
# nice know paid seat sold seat bought rd seat good scam scam same
# i’ll play ear know best buy chewey oatmeal cookies customer care folks
# business class full st class empty guys upgrade exp members st
# trying hours get hold someone
# thank quick responses aa usually fantastic customer service thats shocked
# chances making connection el paso aa dfw sat aa delayed minutes
# beyond frustrated call back auto hold whatever call it entered number cst still call
# ahhhh silence golden now tops all anyone get fired
# hey aa help itinerary plat custy stuck pvr phones working
# wheres dm wheres voucher whos paying cab car back jfk tomorrow
# hold hours
# dislike delays caused crew forgetting load bags amp lazy pilot wanting duty day end
# guys help please
# weather also gross incompetence understaffing crew forgetting load bags duck truth
# robertsamps
# and waited hours stuffy plane could get hrs get luggage americanairlines
# guys another flight today book laguardia louisville ky
# flight tyr tomorrow cancelled flighted due weather long rebook
# aa flight san antonio dallas cancelled flighted
# trying book flight hold cant get representative phone advice
# cancelled flights flights arbitrarily itinerary weekend ruined good reason crew missed monday mtg
# need someone help
# flight cancelled flightled laguardia louisville ky stuck airport guys compensate this
# amp enough staff rude amp ignored passengersdont think accepted whatever reason
# understand weather issue cant expect passengers wait hours inside airports whatever reason outrageous
# guarantee retribution so glad share
# friend flight cancelled flightlations lax cmh feb anyway help her number help
# used call back feature operator regarding flight got call hours late flightr got hung on pleasehelp
# need work tomorrow am therefore help direct message faster calling number backwards
# ugh dump us dfw wno luggage cancelled flight flight times sat arrival tue
# cancelled flights flight send email text call puts way earlier flight might miss now thanks aa
# dming now big thanks
# overweight pull dozen passengers off luggage seriously
# love company staff amazing made uncomfortable situation comfortable
# wait hrs cs call back flt cxldprotection amp hang minute answer st ring
# hold mins cancelled flighted international flight country cant leave call back help
# need place sleep land without accommodations pls
# love new planes jfklax run maybe one day one amenities function nocharge ever
# call chairman call emerald today me call former customer
# flight great fantastic cabin crew a landing thankyou jfk
# flight nycbuenos aires delay since yesterday pm going take pm now give us answers
# flight cancelled flightled cant go home tomorrow could use dinner play first time nyc
# thank you “ customer relations review concerns contact back directly john”
# change flight phone system keeps telling representatives busy
# thanks is
# thx nothing getting us country back us broken plane come on get another one
# “ george look good please follow link start refund process
# flight cancelled flightled leaving tomorrow morning auto rebooked tuesday night flight need arrive monday
# right cue delays
# thank got different flight chicago
# leaving minutes late flight warnings communication minutes late flight thats called shitty customer svc
# please bring american airlines blackberry
# money change flight answer phones suggestions make commitment
# ppl need know many seats next flight plz put us standby people next flight

# %% [markdown]
# ##### 2) Text Vectorization:
# __Convert__ the preprocessed text data into numerical format using `tokenization` and `padding`, so that it can be fed into a deep learning model.

# %%
max_len = 500
tokenizer = Tokenizer(oov_token='<oov>')
tokenizer.fit_on_texts(df['text'])
vocab_size = len(tokenizer.word_index)

X = tokenizer.texts_to_sequences(df['text'])
X_pad = pad_sequences(X, maxlen=max_len)
X_pad
# Out:
# array([[    0,     0,     0, ...,     0,     0,   130],
#        [    0,     0,     0, ...,  2257,   112,  5694],
#        [    0,     0,     0, ...,    75,    70,   107],
#        ...,
#        [    0,     0,     0, ...,   349,   150, 12672],
#        [    0,     0,     0, ...,  1298,    53,  2411],
#        [    0,     0,     0, ...,    66,    96,     2]])

# %% [markdown]
# ##### 3) Model Development:
# __Develop__ a deep learning model using `TensorFlow` and `Keras`. The model includes an `Embedding` layer, a `SpatialDropout1D` layer to prevent overfitting, an `LSTM` layer for sequence data processing, and a `Dense` layer for output. It aims to classify the sentiment of each tweet into one of the `three categories`.

# %%
#sentiment to integer encoded.
sentiment_mapping = {"negative": 0, "neutral": 1, "positive": 2}
df['label'] = df['airline_sentiment'].map(sentiment_mapping).astype(int)
#OHE on sentiment with integer datatype
y_cat = to_categorical(df['label'], num_classes = 3)

# %%
#build model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout1d (SpatialDropout1D) │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### 4) Model Training and Evaluation:
# * __Train__ the model on the processed text data, using `categorical cross-entropy` as the loss function, and `accuracy` as the evaluation metric.
# * Use a `validation split` to __evaluate__ the model's performance and prevent overfitting.

# %%
#compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#train model
history = model.fit(x=X_pad, y=y_cat, batch_size=64, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
#  77/182 ━━━━━━━━━━━━━━━━━━━━ 53s 507ms/step - accuracy: 0.5874 - loss: 0.9796
