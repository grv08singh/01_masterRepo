# %%
#Data Visualization Assignment Quiz - grv08singh@gmail.com

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('home_data.csv')

# %%
df.head(2)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
Sample = [42, 61, 39, 70, 8, 30, 52, 28, 95, 86, 35, 77, 80, 86, 1, 84, 90, 57, 45, 6, 1, 56, 60, 83, 24, 63 ,93 ,59, 92,53]

# %%
a = np.array(Sample)

# %%
np.std(a)
# Out:
# np.float64(28.49491182649983)

# %%
np.var(a)
# Out:
# np.float64(811.9599999999999)

# %%
array = np.array([17, 27, 80, 39, 72, 95, 52, 85, 8, 64, 36, 15, 62, 76, 66, 67, 59, 92])

# %%
np.quantile(array,0.25)
# Out:
# np.float64(36.75)

# %%
np.quantile(array,0.75)
# Out:
# np.float64(75.0)

# %%
np.quantile(array,0.75) - np.quantile(array,0.25)
# Out:
# np.float64(38.25)

# %%
array.max() - array.min()
# Out:
# np.int64(87)

# %%
iqr = 8.25 - 4

# %%
4-1.5*iqr, 8.25+1.5*iqr
# Out:
# (-2.375, 14.625)

# %%
s = [78, 65, 20, 69, 36, 81, 85, 71, 44, 71, 47 ,37, 89, 25, 73, 55, 80, 52, 46, 77]

# %%
a = np.array(s)

# %%
a.mean()
# Out:
# np.float64(60.05)

# %%
a.std()
# Out:
# np.float64(20.095957304890952)

# %%
df = len(a)-1
df
# Out:
# 19

# %%
SE = a.std()/np.sqrt(df)
SE
# Out:
# np.float64(4.610328792933034)

# %%
t = 2.093

# %%
a.mean() - t*SE, a.mean() + t*SE
# Out:
# (np.float64(50.400581836391154), np.float64(69.69941816360884))

# %%
mean = 100
stdev = 15
s = [88, 92, 84, 64, 96, 97, 67, 97, 96, 99,115, 119, 119, 129, 130, 142, 102, 123, 134, 105]
a = np.array(s)

# %%
a.mean() - mean / ()
# Out:
# np.float64(4.900000000000006)

# %%
from statsmodels.stats.weightstats import ztest

# %%
z_stat, p_val = ztest(x1=a, value = mean)

# %%
z_stat
# Out:
# np.float64(1.0308547928995084)

# %%
p_val
# Out:
# np.float64(0.3026089188995713)

# %%
3/13
# Out:
# 0.23076923076923078

# %%
4/13
# Out:
# 0.3076923076923077

# %%
s = [5, 3, 3, 5, 5, 6, 6, 7, 3, 8]
a = np.array(s)
pop_mean = 8
a
# Out:
# array([5, 3, 3, 5, 5, 6, 6, 7, 3, 8])

# %%
from scipy.stats import ttest_1samp

# %%
ttest_1samp(a=a, popmean=pop_mean)
# Out:
# TtestResult(statistic=np.float64(-5.304483619392325), pvalue=np.float64(0.0004909393164477487), df=np.int64(9))

# %%
s1 = [-3, 3, 5, 9, 2, 5, 10, 5, 2, 6]
s2 = [ 6, 7, 8, 7, 3, 12, 7, 10, 6, 11]

a1 = np.array(s1)
a2 = np.array(s2)

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(a1, a2)
# Out:
# TtestResult(statistic=np.float64(-2.2802345265391493), pvalue=np.float64(0.034998593532530806), df=np.float64(18.0))

# %%
69 - 11 + 24
# Out:
# 82

# %%
8/19
# Out:
# 0.42105263157894735

# %%
75/(75+69)
# Out:
# 0.5208333333333334

# %%
80/144
# Out:
# 0.5555555555555556

# %%
ef = .39 + .24
ef
# Out:
# 0.63

# %%
fh = 0.24 + 0.88
fh
# Out:
# 1.12

# %%
ef + fh -0.24
# Out:
# 1.51

# %%
8/21
# Out:
# 0.38095238095238093

# %%
s1=[9.89, 12.34, 3.25, 4.41, 6.17, 14.01] 
s2=[9.32, 9.45, 8.39, 7.82, 9.48, 9.75]

a1 = np.array(s1)
a2 = np.array(s2)

# %%
from scipy.stats import f_oneway

# %%
f_oneway(a1, a2)
# Out:
# F_onewayResult(statistic=np.float64(0.14359377529077166), pvalue=np.float64(0.7126556830955723))
